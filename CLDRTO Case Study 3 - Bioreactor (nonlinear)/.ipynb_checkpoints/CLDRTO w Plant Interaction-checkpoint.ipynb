# %% [markdown]
# **This code computes the decomposed/monolithic solution of a Closed-Loop DRTO problem and implement in the plant.**
#
# - The model is the nonlinear version of the bioreactor of Case Study 2 from:*Gao, Ling. "Modeling and dynamics analyses of immobilized CSTR bioreactor using transfer function model." 2012 International Symposium on Information Technologies in Medicine and Education. Vol. 2. IEEE, 2012.*
# - The underlying control structure (modeled in the CLDRTO model) contains one constrained MPC, which is represented by its KKT conditions in the DRTO problem. The complementarity constraints of the MPC are "moved" to the objective function as a  l1 penalty
# - The problem is posed as a scenario-based stochastic programming problem
# - The uncertainty represented by the scenarios comes from the the maximum reaction rate (Vm)
# - We run a Monte Carlo Analysis of the performance of both strategies for an arbitrary number of scenarios
#
# --> see jupyter notebook "Preliminaries" and "Monolithic and Decomposed CLRTO Comparison" for details
#
# AUTHOR: Jose Matias <assumpcj@mcmaster.ca>
# DATE: September 2023

# %% [markdown]
# [1.Model and Simulation Parameters](#sec1) <br>
# [2.Building Auxiliary Functions](#sec2)<br>
# [2.1. MPC matrices builder](#subsec21)<br>
# [2.2. MPC solver](#subsec22)<br>
# [2.3. Monolithic CLDRTO](#subsec23)<br>
# [2.4. Decomposed CLDRTO](#subsec24)<br>
# [2.5. Plant Model](#subsec25)<br>
# [3. Implementing CL-DRTO in closed loop with the plant](#sec3)<br>

# %%
using LinearAlgebra, JuMP, Ipopt, Plots, LaTeXStrings, CSV, DataFrames, DifferentialEquations, Distributions, Random, Statistics

# %% [markdown]
# <a id="sec1"></a>

# %% [markdown]
# # Model and Simulation Parameters

# %% [markdown]
# - Simulation Parameters

# %%
# Simulation sampling time
dt = 1.0 #[h]

# Integration step (plant)
tspan = (0.0,dt)

# Optimization horizon 
ndrto = 20 + (8 - 1) # p = 8 *controller horizon

# Optimization control horizon 
mD = 20 

# Optimization horizon
Δdrto = 4 # dt_DRTO

# integration (BE) sampling time
n_fe_dt = 5 # number of finite elements/simulation sampling time 

# finite element length
h = dt/n_fe_dt 

# number of finite elements 
nfe = ndrto*n_fe_dt

# Set seed value for choosing the plant parameter 
seed = 42
Random.seed!(seed)

# number of inputs
nu = 1 #[-]
# number of outputs
ny = 1 #[-]
# number of states
nx = 2 # [-]

# INITIAL CONDITION (from paper)
C0 = 0.358 #[g/L]
P0 = 0.642 # [g/L]

# States (algebraic and differential): C, P
x0 = [C0,P0]

# INPUTS (from paper)
Cin0 = 1 #[g/L]
u0 = Cin0;

# %% [markdown]
# - Model Parameters

# %%
# maximum reaction rate (NOTE CHANGE IN PARAMETERS FROM LINEAR)
Vm_nom = 0.75 # [1/h]

# reaction constant (inhibition parameter)
Ks = 0.5 # [g/L]

# Dilution rate ==> D = F/V, Fbar = 2 [L/h], V = 4 [L] 
D = 0.5; # [1/h]

# %%
# Uncertain parameters: Vm 
# nominal value
pNom = 0.75
# standard deviation associated with uncertainty (\pm 20%)
deltaPar = 0.2*pNom;

# %% [markdown]
# - Economic Optimization Problem Parameters

# %%
# feed concentration limitation  (2.0 vs. 5.0)
Cin_max = 5.0 #[g/L] 

# product setpoint limitation
Psp_max = 1.2 # [g/L]

# Soft upper bounds on P weight
pUB = 1.05 # [g/L]

# objective function weight for P penalization term 
wP = 100

# Objective function: target tracking
pTrack = 1.0 # [g/L]

# setting bounds (all arbitrary - not in deviation form!!) 
uMax = 5.0 # [g/L]
uMin = 0.0

yspMax = 1.2 # [g/L]
yspMin = 0.0;

# %% [markdown]
# - MPC Parameters

# %%
##########
# MODELS #
##########
# Linearization point
uref = 1.0
xref = [0.3660;0.6340]
yref = 0.6340

# 100 pre-computed models based on parametric uncertainty Vm (computed using matlab: BioReactorLinearization.m)
bioModels = CSV.read("C:\\Users\\MACC-Jose\\Documents\\GitHub\\BD\\CLDRTO Case Study 3 - Bioreactor (nonlinear)\\BioreactorModel", DataFrame; header=false);
#print(bioModels)

# extracting the matrices from the model array computed previously
nNom = 50 # nominal model --> index = 50

A = Matrix(bioModels[2*(nNom - 1) + 1:2*(nNom - 1) + 2,1:2]) 
B = bioModels[2*(nNom - 1) + 1:2*(nNom - 1) + 2,3]
C = [0 1];

# initial value of xMPC
xMPC0 = x0 - xref
de0 = 0

##########
# TUNING #
##########
# prediction horizon 
p = 8

# control horizon 
m = 2

# output tracking weight
q = 1

# move supression weight
r = 1

# input bounds (not in deviation form)
u_mpc_lb = 0.0
u_mpc_ub = Cin_max

##################
# KKT CONDITIONS #
##################
# matrix to compute the gradients of the input bound constraints
conMatrix = [-I(m); I(m)]

# regularization term OF for complementarities (1e1)
rho_cc = 1e1;

# %% [markdown]
# - Preparing Orthogonal Collocation

# %%
# Parameters for orthogonal collocation
#  Radau Collocation Points 1st degree polynomial == Backward Euler
radau  = [0.0 1.00000]

# number of collocation points (initial point is also considered)
ncp = length(radau) 

# Collocation parameters and radau time series
colmat = [-1.0 -1.0;
          1.0 1.0];

# %% [markdown]
# - Bender's Decomposition

# %%
# max number of iteration (50)
benIterMax = 150

# optimality gap (relative) tolerance (1e-2)
optGap = 1e-3

# parameter that weights the nominal trajectory tracking term (1e-2)
η_n = 0.0;

# %% [markdown]
# <a id="sec2"></a>

# %% [markdown]
# # Building auxiliary functions

# %% [markdown]
# <a id="subsec21"></a>

# %% [markdown]
# ## MPC matrices builder

# %%
function MPC_matrices(A,B,C,p,m,q,r)
    ###########
    # inputs: #
    ###########
    # A,B,C - System model
    # p, m - prediction and control horizon
    # q, r - setpoint and input usage tuning parameters
    
    # extracting dimensions from system model
    nx = size(A,1) # states
    nu = size(B,2) # inputs
    ny = size(C,1) # outputs
    
    # adding disturbance model
    Ad = [A zeros(nx,ny); zeros(ny,nx) I(ny)]
    Bd = [B; zeros(ny,nu)]
    Cd = [C ones(ny,ny)]
    
    # building matrices for MPC
    Psi = Cd*Ad
    for ii in 2:p
        Psi = [Psi;  Cd*Ad^ii]
    end

    # Computing Dynamic Matrix
    a = Cd*Bd
    for ii in 2:p
        a = [a; Cd*Ad^(ii - 1)*Bd]
    end
    DynM = a

    for ii in 1:(m - 2)
        a = [zeros(ny,nu);a[1:(p-1)*ny,:]]
        DynM = [DynM  a]
    end

    # adjusting dynamic matrix for since p > m (last column)
    b = Cd*Bd

    Ai = I(nx+1) # adding disturbance to the states
    for ii = 1:(p - m)
        Ai = Ai + Ad^ii
        b = [b;Cd*Ai*Bd]
    end

    Theta=[DynM [zeros(ny*(m-1),nu);b]]
    
    # Creating Qbar and Rbar matrices
    Qbar = Diagonal([q for ii in 1:p])
    Rbar = Diagonal([r for ii in 1:m])

    # Creating input movement OF penalty matrix 
    M=[zeros((m-1)*nu,nu) I(nu*(m-1)); zeros(nu) zeros(nu,nu*(m-1))]
    Ibar=[I(nu); zeros(nu*(m-1),nu)]
    IM = I(nu*m) - M';
    
    # Matrix H
    H = Theta'*Qbar*Theta + IM'*Rbar*IM;
    
    return Dict('A' => A, 'B' => B, 'C' => C, 'H' => H, 'Θ' => Theta, 'Ψ' => Psi, 'Q' => Qbar, 'I' => Ibar, 'R' => Rbar, 'M' => IM)
end;

# %% [markdown]
# <a id="subsec23"></a>

# %% [markdown]
# ## MPC solver
#
# - Building function for computing MPC solution (solving QP)

# %%
function solveMPC(xkk,dekk,uk_1,yspk,umin,umax,yref,uref,mpc,p,m)
    ###########
    # inputs: #
    ###########
    # xkk - current states (MPC model) 
    # dekk - disturbance estimate 
    # uk_1 - inputs at the current iteration, already implemented on the plant
    # yspk - setpoint trajectory computed by CL-DRTO
    # umin, umax - input bounds
    # yref, uref - reference points for computing deviation variables
    # mpcModel - System model
    # p, m - prediction and control horizon
    
    MPC_con = Model(Ipopt.Optimizer)
    set_silent(MPC_con)
    
    ####################
    # Set up variables #
    ####################
    # inputs computed by MPCs
    @variable(MPC_con, (umin - uref) ≤ u[1:m] ≤ (umax - uref))
    
    ######################
    # Set up expressions #
    ######################
    @expression(MPC_con, cfT, (mpc['Ψ']*[xkk;dekk] - (yspk .- yref))'*mpc['Q']*mpc['Θ'] - (uk_1 - uref)'*mpc['I']'*mpc['R']*mpc['M'])
    
    
    # Option 1. solving as a constrained MPC
    @objective(MPC_con, Min, sum(u[jj]*sum(mpc['H'][jj,ii]*u[ii] for ii in 1:m) for jj in 1:m) + 2*sum(cfT[jj]*u[jj] for jj = 1:m))

    # Option 2. solving exactly like in the CLDRTO implementation (for debugging)
    #@constraint(MPC_con, MPCsol[jj = 1:m], sum(mpc['H'][jj,ii]*u[ii] for ii in 1:m) + cfT[jj] == 0.0)    
    #@objective(MPC_con, Min, -1)

    #################
    # Solve Problem #
    #################
    optimize!(MPC_con)
    
    if has_values(MPC_con)
        flag = 1
    else
        flag = 0
    end

    #calling values of the solved problem
    ϕ = objective_value(MPC_con)
    uArray = value.(u) .+ uref
    return Dict('ϕ' => ϕ,'u' => uArray, 'f' => flag)
end;

# %% [markdown]
# <a id="subsec23"></a>

# %% [markdown]
# ## Monolithic solution of scenario-based CLDRTO

# %%
function MS_CLDRTO(C_0,P_0,u_0,xMPC_0,de_0,VmTemp,ns,solNom)
    ###########
    # inputs: #
    ###########
    # C_0, P_0 - substrate and biomass concentration at the current iteration (beginning of DRTO horizon)
    # u_0 - current input implemented in the plant
    # xMPC_0 - current MPC states
    # de_0 - current plant/MPC model deviation
    # VmTemp - vector containing all the values of the uncertain paramete
    # nScen - number of scenarios
    # solNom - nominal solution
    
    # Assuming equiprobable scenarios
    pScen = 1.0/ns
    
    # JuMP model
    model_ms = Model(Ipopt.Optimizer)
    set_optimizer_attribute(model_ms, "warm_start_init_point", "yes")
    #set_optimizer_attribute(model_ms, "print_level", 5)
    set_optimizer_attribute(model_ms, "max_cpu_time", 300.0) # 5 min
    set_silent(model_ms)

    ####################
    # Set up variables #
    ####################
     # DRTO model variables
    @variable(model_ms, C[1:nfe, 1:ncp, 1:ns] ≥ 0.0)    # [g/L] substrate concentration (diff states)
    @variable(model_ms, P[1:nfe, 1:ncp, 1:ns] ≥ 0.0)    # [g/L] biomass concentration (diff states)
    @variable(model_ms, Cdot[1:nfe, 1:ncp, 1:ns])       # [g/L/h] substrate concentration (time derivative)
    @variable(model_ms, Pdot[1:nfe, 1:ncp, 1:ns])       # [g/L/h] biomass concentration (time derivative)
    @variable(model_ms, delta_p[1:nfe, 1:ns] ≥ 0.0)     # [g/L] soft constraint on P
    @variable(model_ms, 0.0 ≤ Cin[1:ndrto, 1:ns] ≤ Cin_max) # [g/L] substrate feed to reactor

    # MPC model variables (SISO) -> deviation form
    @variable(model_ms, xMPC[1:nx,1:ndrto, 1:ns])
    @variable(model_ms, uMPC[1:ndrto,1:m, 1:ns]) 

    # MPC <-> DRTO model deviation
    @variable(model_ms, de[1:(ndrto - 1), 1:ns])

    # Constrained MPC KKT conditions (upper and lower bounds for each input)
    @variable(model_ms, mu_g[1:mD,1:(2*m), 1:ns] ≥ 0, start = 0) 

    # setpoints for the controllers sent to the plant (*CL-DRTO degrees of freedom)
    @variable(model_ms, yspMin ≤ ysp[1:ndrto, 1:ns] ≤ yspMax)

    
    # non-anticipativity constraints
    @variable(model_ms, yspMin ≤ yspNA[1:Δdrto] ≤ yspMax)
    
    #####################################
    # Set up initial guesses for solver #
    #####################################
    if solNom isa Dict # if gives flexibility to NOT initialize variables
        for ss in 1:ns
            for kk in 1:nfe
                for jj in 1:ncp
                    set_start_value(C[kk,jj,ss], solNom['C'][kk,jj,1])
                    set_start_value(P[kk,jj,ss], solNom['P'][kk,jj,1])
                end # collocation points loop
            end # end finite elements loop
            
            for kk in 1:ndrto
                # MV's
                set_start_value(Cin[kk,ss], solNom['I'][kk,1])
                
                for mm in 1:m
                    set_start_value(uMPC[kk,mm,ss], solNom['I'][kk,1] - uref)
                end
            end
            
            for kk in 1:mD
                for mm in 1:(2*m)
                    set_start_value(mu_g[kk,mm,ss], solNom['μ'][kk,mm,1])
                end
            end # drto sampling time loop
        end # scenarios loop
    else
        # Set up initial guesses for solver: using opt. steady-state previoulsy computed
        for ss in 1:ns
            for kk in 1:nfe
                for jj in 1:ncp
                    set_start_value(C[kk,jj,ss], C0) 
                    set_start_value(P[kk,jj,ss], P0)
                end # collocation points loop
            end # finite elements loop

            for kk in 1:ndrto
                # MV's
                set_start_value(Cin[kk,ss], Cin0)

                for mm in 1:m
                    set_start_value(uMPC[kk,mm,ss], Cin0 - uref)
                end
            end 
        end # scenarios loop
    end
    
    ##############
    # DRTO model #
    ##############
    # [g/L/h] Immobilized enzyme or cell catalytic reaction rate (defined by Michaelis-Menten equation)
    @NLexpression(model_ms, rc[kk = 1:nfe, jj = 1:ncp, ss = 1:ns], Vm_nom*C[kk,jj,ss]/(Ks + C[kk,jj,ss]))

    @NLconstraints(model_ms, begin
        #########
        # MODEL #
        #########    
        # reactor
        r_C[kk = 1:nfe, jj = 1:ncp, ss = 1:ns], Cdot[kk,jj,ss] == D*(Cin[cld(kk,n_fe_dt),ss] - C[kk,jj,ss]) - rc[kk,jj,ss] 
        r_P[kk = 1:nfe, jj = 1:ncp, ss = 1:ns], Pdot[kk,jj,ss] == rc[kk,jj,ss] - D*P[kk,jj,ss]
        #########################    
        # Collocation Equations #    
        #########################
        # initial point
        coll_C_0[ss = 1:ns], C[1,1,ss] == C_0 
        coll_P_0[ss = 1:ns], P[1,1,ss] == P_0  
        # set up collocation equations 
        coll_C_n[kk = 1:nfe, jj = 2:ncp, ss = 1:ns], sum(colmat[ii,jj]*C[kk,ii,ss] for ii in 1:ncp) - h*Cdot[kk,jj,ss] == 0 
        coll_P_n[kk = 1:nfe, jj = 2:ncp, ss = 1:ns], sum(colmat[ii,jj]*P[kk,ii,ss] for ii in 1:ncp) - h*Pdot[kk,jj,ss] == 0
        # continuinity equations
        coll_C_con[kk = 2:nfe, ss = 1:ns], C[kk,1,ss] - C[kk - 1,ncp,ss] == 0 
        coll_P_con[kk = 2:nfe, ss = 1:ns], P[kk,1,ss] - P[kk - 1,ncp,ss] == 0 
    end)

    ##########################
    # MPC model and solution #
    ##########################
    # N.B. inside MPC everything is in deviation variables
    @expressions(model_ms, begin
        cfT_1[ss = 1:ns], (mpc['Ψ']*[xMPC_0;de_0] - (ysp[1:p,ss] .- yref))'*mpc['Q']*mpc['Θ'] - (u0 - uref)*mpc['I']'*mpc['R']*mpc['M']
        cfT[kk = 1:(mD - 1),ss = 1:ns], (mpc['Ψ']*[xMPC[:,kk,ss];de[kk,ss]] - (ysp[(kk + 1):(kk + 1 + p - 1),ss] .- yref))'*mpc['Q']*mpc['Θ'] - uMPC[kk,1,ss]*mpc['I']'*mpc['R']*mpc['M']
        # Input bounds
        MPC_u_upper[kk = 1:mD,uu = 1:m,ss = 1:ns], (uMax - uref) - uMPC[kk,uu,ss]
        MPC_u_lower[kk = 1:mD,uu = 1:m,ss = 1:ns], uMPC[kk,uu,ss] - (uMin - uref)
    end)

    @constraints(model_ms, begin
        #############
        # MPC model #
        #############
        MPC_dyn_model_1[ss = 1:ns], xMPC[:,1,ss] .== mpc['A']*xMPC_0 + mpc['B']*(u0 - uref)
        MPC_dyn_model[kk = 1:(ndrto - 1),ss = 1:ns], xMPC[:,kk + 1,ss] .== mpc['A']*xMPC[:,kk,ss] + mpc['B']*uMPC[kk,1,ss]
        MPC_model_dev[kk = 1:(ndrto - 1),ss = 1:ns], de[kk,ss] == (P[kk,ncp,ss] - yref) - xMPC[2,kk,ss]
        ################
        # MPC solution #
        ################
        # stationarity
        MPC_sol_sta_1[ss = 1:ns], uMPC[1,:,ss]'*mpc['H'] + cfT_1[ss] +  mu_g[1,:,ss]'*conMatrix .== 0
        MPC_sol_sta[kk = 1:(mD - 1), ss = 1:ns], uMPC[kk + 1,:,ss]'*mpc['H'] + cfT[kk,ss] +  mu_g[kk + 1,:,ss]'*conMatrix .== 0
        # primal feasibility
        MPC_sol_feas_ub[kk = 1:mD,uu = 1:m,ss = 1:ns], MPC_u_upper[kk,uu,ss] ≥ 0
        MPC_sol_feas_lb[kk = 1:mD,uu = 1:m,ss = 1:ns], MPC_u_lower[kk,uu,ss] ≥ 0
    end)
    
    @constraints(model_ms, begin   
        ###############
        # CONSTRAINTS #
        ###############
        # ! Enforcing only at the end of the finite element
        # P soft constraints
        soft_P[kk = 1:nfe,ss = 1:ns], P[kk,ncp,ss] - delta_p[kk,ss] ≤ pUB
        # fixing setpoint changes after mD
        control_horizon[kk = (mD+1):ndrto,uu = 1:m,ss = 1:ns], uMPC[kk,uu,ss] == uMPC[mD,uu,ss]
        ############################
        # OPTIMIZATION CONSTRAINTS #
        ############################
        # connecting the MPC solution to the DRTO model (only the first element of the MV* is implemented)
        hc[kk = 1:ndrto,ss = 1:ns], (uMPC[kk,1,ss] + uref) - Cin[kk,ss] == 0.0
        ##################################
        # NON-ANTICIPATIVITY CONSTRAINTS #
        ##################################
        nonAnt[kk = 1:Δdrto,ss = 1:ns], ysp[kk,ss] - yspNA[kk] == 0.0
    end)
    
    # Set up objective function     
    if ns > 1    
        @NLobjective(model_ms, Min, pScen*sum(sum((P[kk,ncp,ss] - pTrack)^2 + wP*delta_p[kk,ss]^2 for kk in 1:nfe)
        + rho_cc*sum(mu_g[kk,uu,ss]*MPC_u_upper[kk,uu,ss] + mu_g[kk,m + uu,ss]*MPC_u_lower[kk,uu,ss] for uu = 1:m, kk = 1:mD) 
        for ss in 1:ns) +  η_n*sum((yspNA[kk] - solNom['s'][kk,1])^2 for kk in 1:Δdrto))
    else
        @NLobjective(model_ms, Min, pScen*sum(sum((P[kk,ncp,ss] - pTrack)^2 + wP*delta_p[kk,ss]^2 for kk in 1:nfe)
        + rho_cc*sum(mu_g[kk,uu,ss]*MPC_u_upper[kk,uu,ss] + mu_g[kk,m + uu,ss]*MPC_u_lower[kk,uu,ss] for uu = 1:m, kk = 1:mD) 
        for ss in 1:ns))
    end
    
    #################
    # Solve Problem #
    #################
    optimize!(model_ms)
    
    status = termination_status(model_ms)
    #display(status)
    
    if status == MOI.OPTIMAL || status == MOI.ALMOST_OPTIMAL || status == MOI.LOCALLY_SOLVED
        # Proved optimality or Optimal within relaxed tolerances
        # solution time
        timeSol = solve_time(model_ms)

        flag = 1
        # #primal_status(m)

        #calling values of the solved problem
        ϕ = objective_value(model_ms)
        yspArray = value.(ysp)
        CArray = value.(C)
        PArray = value.(P)
        CinArray = value.(Cin)
        
        muArray = value.(mu_g)
        
        outputFun = Dict('ϕ' => ϕ,
                        't' => timeSol,
                        'f' => flag, 
                        's' => yspArray,
                        'I' => CinArray,
                        'C' => CArray,
                        'P' => PArray,
                        'μ' => muArray)
        
        return outputFun
    else
        # Handle other cases.
        outputFun = Dict('f' => 0,
                         't' => NaN,
                         'ϕ' => NaN)
                        
        
        return outputFun
    end
end;

# %% [markdown]
# <a id="subsec24"></a>

# %% [markdown]
# ## Decomposed CLDRTO

# %% [markdown]
# - Modeling Subproblem

# %%
function subp(yspFixed,C_0,P_0,u_0,xMPC_0,de_0,VmScen,pScen,solNom)    
    ###########
    # inputs: #
    ###########
    # yspFixed - setpoints determined by the master problem 
    # C_0, P_0 - substrate and biomass concentration at the current iteration (beginning of DRTO horizon)
    # u_0 - current input implemented in the plant
    # xMPC_0 - current MPC states
    # de_0 - current plant/MPC model deviation
    # VmScen - vector containing the values of the uncertain parameter for a given scenario
    # pScen - probability of a given scenario
    # solNom - nominal solution
    
    # JuMP model
    model_sub = Model(Ipopt.Optimizer)
    set_optimizer_attribute(model_sub, "warm_start_init_point", "yes")
    #set_optimizer_attribute(model_sub, "print_level", 5)
    set_optimizer_attribute(model_sub, "max_cpu_time", 300.0) # 5 min
    set_silent(model_sub)
    
     ####################
    # Set up variables #
    ####################
     # DRTO model variables
    @variable(model_sub, C[1:nfe, 1:ncp] ≥ 0.0)    # [g/L] substrate concentration (diff states)
    @variable(model_sub, P[1:nfe, 1:ncp] ≥ 0.0)    # [g/L] biomass concentration (diff states)
    @variable(model_sub, Cdot[1:nfe, 1:ncp])       # [g/L/h] substrate concentration (time derivative)
    @variable(model_sub, Pdot[1:nfe, 1:ncp])       # [g/L/h] biomass concentration (time derivative)
    @variable(model_sub, delta_p[1:nfe] ≥ 0.0)     # [g/L] soft constraint on P
    @variable(model_sub, 0.0 ≤ Cin[1:ndrto] ≤ Cin_max) # [g/L] substrate feed to reactor

    # MPC model variables (SISO) -> deviation form
    @variable(model_sub, xMPC[1:nx,1:ndrto])
    @variable(model_sub, uMPC[1:ndrto,1:m]) 

    # MPC <-> DRTO model deviation
    @variable(model_sub, de[1:(ndrto - 1)])

    # Constrained MPC KKT conditions (upper and lower bounds for each input)
    @variable(model_sub, mu_g[1:mD,1:(2*m)] ≥ 0, start = 0) 

    # setpoints for the controllers sent to the plant (*CL-DRTO degrees of freedom)
    @variable(model_sub, yspMin ≤ ysp[1:ndrto] ≤ yspMax)
    
    #####################################
    # Set up initial guesses for solver #
    #####################################
    if solNom isa Dict # if gives flexibility to NOT initialize variables
        for kk in 1:nfe
            for jj in 1:ncp
                set_start_value(C[kk,jj], solNom['C'][kk,jj,1])
                set_start_value(P[kk,jj], solNom['P'][kk,jj,1])
            end # collocation points loop
        end # end finite elements loop

        for kk in 1:ndrto
            # MV's
            set_start_value(Cin[kk], solNom['I'][kk,1])

            for mm in 1:m
                set_start_value(uMPC[kk,mm], solNom['I'][kk,1] - uref)
            end
        end
            
        for kk in 1:mD
            for mm in 1:(2*m)
                set_start_value(mu_g[kk,mm], solNom['μ'][kk,mm,1])
            end
        end # drto sampling time loop
    else
    # Set up initial guesses for solver: using opt. steady-state previoulsy computed
        for kk in 1:nfe
            for jj in 1:ncp
                set_start_value(C[kk,jj], C0) 
                set_start_value(P[kk,jj], P0)
            end # collocation points loop
        end # finite elements loop

        for kk in 1:ndrto
            # MV's
            set_start_value(Cin[kk], Cin0)

            for mm in 1:m
                set_start_value(uMPC[kk,mm], Cin0 - uref)
            end
        end 
    end
    
    ##############
    # DRTO model #
    ##############
    # [g/L/h] Immobilized enzyme or cell catalytic reaction rate (defined by Michaelis-Menten equation)
    @NLexpression(model_sub, rc[kk = 1:nfe, jj = 1:ncp], Vm_nom*C[kk,jj]/(Ks + C[kk,jj]))

    @NLconstraints(model_sub, begin
        #########
        # MODEL #
        #########    
        # reactor
        r_C[kk = 1:nfe, jj = 1:ncp], Cdot[kk,jj] == D*(Cin[cld(kk,n_fe_dt)] - C[kk,jj]) - rc[kk,jj] 
        r_P[kk = 1:nfe, jj = 1:ncp], Pdot[kk,jj] == rc[kk,jj] - D*P[kk,jj]
        #########################    
        # Collocation Equations #    
        #########################
        # initial point
        coll_C_0, C[1,1] == C_0 
        coll_P_0, P[1,1] == P_0  
        # set up collocation equations 
        coll_C_n[kk = 1:nfe, jj = 2:ncp], sum(colmat[ii,jj]*C[kk,ii] for ii in 1:ncp) - h*Cdot[kk,jj] == 0 
        coll_P_n[kk = 1:nfe, jj = 2:ncp], sum(colmat[ii,jj]*P[kk,ii] for ii in 1:ncp) - h*Pdot[kk,jj] == 0
        # continuinity equations
        coll_C_con[kk = 2:nfe], C[kk,1] - C[kk - 1,ncp] == 0 
        coll_P_con[kk = 2:nfe], P[kk,1] - P[kk - 1,ncp] == 0 
    end)

    ##########################
    # MPC model and solution #
    ##########################
    # N.B. inside MPC everything is in deviation variables
    @expressions(model_sub, begin
        cfT_1, (mpc['Ψ']*[xMPC_0;de_0] - (ysp[1:p] .- yref))'*mpc['Q']*mpc['Θ'] - (u0 - uref)*mpc['I']'*mpc['R']*mpc['M']
        cfT[kk = 1:(mD - 1)], (mpc['Ψ']*[xMPC[:,kk];de[kk]] - (ysp[(kk + 1):(kk + 1 + p - 1)] .- yref))'*mpc['Q']*mpc['Θ'] - uMPC[kk,1]*mpc['I']'*mpc['R']*mpc['M']
        # Input bounds
        MPC_u_upper[kk = 1:mD,uu = 1:m], (uMax - uref) - uMPC[kk,uu]
        MPC_u_lower[kk = 1:mD,uu = 1:m], uMPC[kk,uu] - (uMin - uref)
    end)

    @constraints(model_sub, begin
        #############
        # MPC model #
        #############
        MPC_dyn_model_1, xMPC[:,1] .== mpc['A']*xMPC_0 + mpc['B']*(u0 - uref)
        MPC_dyn_model[kk = 1:(ndrto - 1)], xMPC[:,kk + 1] .== mpc['A']*xMPC[:,kk] + mpc['B']*uMPC[kk,1]
        MPC_model_dev[kk = 1:(ndrto - 1)], de[kk] == (P[kk,ncp] - yref) - xMPC[2,kk]
        ################
        # MPC solution #
        ################
        # stationarity
        MPC_sol_sta_1, uMPC[1,:]'*mpc['H'] + cfT_1 +  mu_g[1,:]'*conMatrix .== 0
        MPC_sol_sta[kk = 1:(mD - 1)], uMPC[kk + 1,:]'*mpc['H'] + cfT[kk] +  mu_g[kk + 1,:]'*conMatrix .== 0
        # primal feasibility
        MPC_sol_feas_ub[kk = 1:mD,uu = 1:m], MPC_u_upper[kk,uu] ≥ 0
        MPC_sol_feas_lb[kk = 1:mD,uu = 1:m], MPC_u_lower[kk,uu] ≥ 0
    end)
    
    @constraints(model_sub, begin   
        ###############
        # CONSTRAINTS #
        ###############
        # ! Enforcing only at the end of the finite element
        # P soft constraints
        soft_P[kk = 1:nfe], P[kk,ncp] - delta_p[kk] ≤ pUB
        # fixing setpoint changes after mD
        control_horizon[kk = (mD+1):ndrto,uu = 1:m], uMPC[kk,uu] == uMPC[mD,uu]
        ############################
        # OPTIMIZATION CONSTRAINTS #
        ############################
        # connecting the MPC solution to the DRTO model (only the first element of the MV* is implemented)
        hc[kk = 1:ndrto], (uMPC[kk,1] + uref) - Cin[kk] == 0.0
        ##################################
        # NON-ANTICIPATIVITY CONSTRAINTS #
        ##################################
        nonAnt[kk = 1:Δdrto], ysp[kk] - yspFixed[kk] == 0.0
    end)
    
    # Set up objective function      
    @NLobjective(model_sub, Min, pScen*(sum((P[kk,ncp] - pTrack)^2 + wP*delta_p[kk]^2 for kk in 1:nfe)
    + rho_cc*sum(mu_g[kk,uu]*MPC_u_upper[kk,uu] + mu_g[kk,m + uu]*MPC_u_lower[kk,uu] for uu = 1:m, kk = 1:mD)))
    
    #################
    # Solve Problem #
    #################    
    optimize!(model_sub)
    
    # solution time
    timeSol = solve_time(model_sub)
    
    status = termination_status(model_sub)
    #display(status)
    
    # checking if there is a solution to the problem
    if status == MOI.ALMOST_LOCALLY_SOLVED || status == MOI.LOCALLY_SOLVED
        # Proved optimality or Optimal within relaxed tolerances
        # we add an optimality cut
        flag = 1
        # #primal_status(m)

        #calling values of the solved problem
        ϕ = objective_value(model_sub)
        yspArray = value.(ysp)
        CArray = value.(C)
        PArray = value.(P)
        CinArray = value.(Cin)
        
        muArray = value.(mu_g)
        
        # lagrange multipliers associated with the nonantecipativity constraints
        λ = dual.(nonAnt)
        
        outputDict = Dict('ϕ' => ϕ,
                        't' => timeSol,
                        'f' => flag, 
                        'a' => status,
                        's' => yspArray,
                        'I' => CinArray,
                        'C' => CArray,
                        'P' => PArray, 
                        'μ' => muArray,
                        'λ' => λ)
        
        return outputDict
    else
        #i.e. no feasible solution --> Add feasibility cut
        #display("Feasibility cut: scenario $(scen)")        
        
        # ! soft bounds on ysp
        delete_lower_bound.(ysp[1:pD])
        delete_upper_bound.(ysp[1:pD])
           
        # ! soft bounds on u
        delete(model_sub, MPC_sol_feas_ub)
        delete(model_sub, MPC_sol_feas_lb)
        unregister(model_sub, :MPC_sol_feas_ub)
        unregister(model_sub, :MPC_sol_feas_lb)
        
        ####################
        # Set up variables #
        ####################    
        # slack variables
        @variable(model_sub, delta_ysp_u[1:ndrto] ≥ 0.0)
        @variable(model_sub, delta_ysp_l[1:ndrto] ≥ 0.0)
        @variable(model_sub, delta_u_u[1:mD,1:m] ≥ 0.0)
        @variable(model_sub, delta_u_l[1:mD,1:m] ≥ 0.0)
        
        ###########################
        # Always-feasible problem #
        ###########################        
        @constraint(model_sub, soft_ysp_upper[kk = 1:ndrto], ysp[kk] - yspMax ≤ delta_ysp_u[kk])
        @constraint(model_sub, soft_ysp_lower[kk = 1:ndrto], yspMin - ysp[kk] ≤ delta_ysp_l[kk])
        @constraint(model_sub, soft_u_upper[kk=1:mD,uu=1:m], u[kk,uu] - (uMax - u0) ≤ delta_u_u[kk,uu])
        @constraint(model_sub, soft_u_lower[kk=1:mD,uu=1:m], (uMin - u0) - u[kk,uu] ≤ delta_u_l[kk,uu])
        
       #############################
        # Set up objective function #
        #############################
        # Modifying the objective --> minimizing constraint violation
        @objective(model_sub, Min, sum(delta_p[kk] for kk in 1:nfe) 
            + sum(delta_ysp_u[kk] + delta_ysp_l[kk] for kk in 1:ndrto)
            + sum(delta_u_u[kk,uu] + delta_u_l[kk,uu] for uu in 1:m, kk in 1:mD))
      

        #@show sub
        # re-optimizing (now using the always feasible problem)
        optimize!(model_sub)
        
        # objective function of the feasibility problem
        o = objective_value(model_sub)

        # solution time (adding time to solve the always feasible subproblem)
        timeSol = solve_time(model_sub)
        
        # checking status of the solution
        status_sub = termination_status(model_sub)
        
        # flag for calling feasibility cuts (not optimality cuts)
        flag = 0
        
        #calling values of the solved problem
        yspArray = value.(ysp)
        CinArray = value.(Cin)
        CArray = value.(C)
        PArray = value.(P)
        muArray = value.(mu_g)
        
        #slacks
#         dysp_ub = value.(delta_ysp_u)
#         dysp_lb = value.(delta_ysp_l)
#         temp1 = sum(dysp_ub[kk] + dysp_lb[kk] for kk in 1:ndrto)
#         display("DB: SP slacks sum: $(temp1)")
        
#         dc_ub = value.(delta_u_u)
#         dc_lb = value.(delta_u_l)
#         temp2 = sum(sum(dc_ub[kk,uu] + dc_lb[kk,uu] for uu in 1:m) for kk in 1:mD)
#         display("DB: MPC input slacks sum: $(temp2)")
        
        # lagrange multipliers associated with the nonantecipativity constraints
        λ = dual.(nonAnt)
        
        outputDict = Dict('ϕ' => o,
                        't' => timeSol,
                        'f' => flag, 
                        'a' => status_sub,
                        's' => yspArray,
                        'I' => CinArray,
                        'C' => CArray,
                        'P' => PArray,
                        'μ' => muArray,
                        'λ' => λ)
        
        return outputDict
    end
end;

# %% [markdown]
# - Modeling Master problem

# %%
## Modeling Benders Decompostion
function BENS_CLDRTO(C_0,P_0,u_0,xMPC_0,de_0,VmTemp,ns,solNom)
    ###########
    # inputs: #(xInit,uInit,nReac,nScen,pScen,solNom,option)
    ###########
    # C_0, P_0 - substrate and biomass concentration at the current iteration (beginning of DRTO horizon)
    # u_0 - current input implemented in the plant
    # xMPC_0 - current MPC states
    # de_0 - current plant/MPC model deviation
    # VmTemp - vector containing all the values of the uncertain parameter (Vm)
    # ns - number of scenarios
    # solNom - nominal solution
    
    # saving opt gap array
    optGapArray = Vector{Float64}()
    
    # Assuming equiprobable scenarios
    pScen = 1.0/ns
    
    # flag for checking if last cut was opt. (1) or feas. (0)
    flagO = 1
    
    # timing solution via Benders
    timeSolBen = 0 
    # timing solution via parallel Benders
    timeSolParBen = 0 
    
    # Define master problem model
    master = Model(Ipopt.Optimizer)
    set_silent(master)
    
    #lower bound on scenario objective function approximation 
    alpha_down = 0.0; 
    
    # defining temp solution to avoid loop's scope
     ysp_nonⁱ = Vector{Float64}(undef,Δdrto)
    
    ####################
    # Set up variables #
    ####################
    # setpoints for the controllers sent to the plant
    @variable(master, yspMin ≤ ysp[1:Δdrto] ≤ yspMax)
    @variable(master, α ≥ alpha_down)
    
    ################################################
    # Solving problem with benders' decomposition  #
    ################################################
    for ii in 1:benIterMax
        
        ########################
        # Set up initial guess #
        ########################
        # check size of the optimality gap array
        s_opt_array = size(optGapArray)
        
        # always use nominal solution in the first iteration
        if ii == 1 
            for kk in 1:Δdrto
                set_start_value(ysp[kk], solNom['s'][kk,1])
            end 
        # check if MASTER problem got stuck in a solution, in this case use random guess   
        elseif s_opt_array[1] > 1 && abs(optGapArray[end] - optGapArray[end - 1]) < 0.001
            tempGuess = rand(Uniform(yspMin,yspMax),Δdrto)
            display("DB: random")

            for kk in 1:Δdrto
                set_start_value(ysp[kk], tempGuess[kk])
            end  
        # otherwise use previous solution
        else    
            for kk in 1:Δdrto
                set_start_value(ysp[kk],  ysp_nonⁱ[kk])
            end 
        end
          
        #############################
        # Set up objective function #
        #############################
        # "nudge" next solution towards nominal solution (working = 1e-4)
        @objective(master, Min, α + η_n*sum((ysp[kk] - solNom['s'][kk,1])^2 for kk in 1:Δdrto))
        
        # solve master problem (with Benders' cut)
        optimize!(master)

        # solution time
        timeSolMaster = solve_time(master)
        # extracting solution for the non-anticipativity constraints
        ysp_nonⁱ = value.(ysp) 
        
        # Master problem solution: lower bound of the original problem
        lb = value(α)
        
        timeSolBen = timeSolBen + timeSolMaster
        timeSolParBen = timeSolParBen + timeSolMaster # master cannot be paralellized 

        #######################
        # Solving subproblems #
        #######################
        # objective function
        o_temp = Vector{Float64}(undef,ns)
        # flag optimality / feasibility
        flag_temp = Vector{Float64}(undef,ns)
        # solution time
        solTime_temp = Vector{Float64}(undef,ns)
        # multipliers
        lambdaN_temp = Matrix{Float64}(undef,Δdrto,ns)
        
        for ss in 1:ns
            dicTemp = subp(ysp_nonⁱ,C_0,P_0,u_0,xMPC_0,de_0,VmTemp[ss],pScen,solNom)

            # saving files
            # objective function
            o_temp[ss] = dicTemp['ϕ']
            # solution time
            solTime_temp[ss] = dicTemp['t']
            # optimality / feasibility flag
            flag_temp[ss] = dicTemp['f']
            # multiplier
            for kk in 1:Δdrto
                lambdaN_temp[kk,ss] = dicTemp['λ'][kk]
            end
        end
        
        ##########################################################
        # If all subproblems were feasible, check optimality gap #
        ##########################################################
        if sum(flag_temp) == ns 
            # Subproblem solution: upper bound of the original problem
            ub = sum(o_temp)

            # solve subproblems to find the upper bound of the original problem solution 
            timeSolBen = timeSolBen + sum(solTime_temp)

            # assuming that subproblem solution is parallelized
            timeSolParBen = timeSolParBen + maximum(solTime_temp)   
            
            # compute optimality gap
            gap = abs(ub - lb)/abs(ub)
            display("DB: opt. gap $(gap)")
            push!(optGapArray, gap)
            
            # check if optimality gap is small enough
            # also, make sure last cut was an optimality cut due to change in OF 
            if gap < optGap && flagO == 1
                global yspSol_dec = ysp_nonⁱ
                global objFun_dec = ub
                global optGap_dec = gap
                global iter_dec = ii
                global time_dec = timeSolBen
                global time_max_dec = timeSolParBen
                break
            else # gap ≥ optGap 
                ##############################
                # --> adding optimality cuts #
                ##############################
                display(">>>>>> iteration $(ii):O")
                benderscutO = @constraint(master, α ≥ ub + 
                    sum(sum(lambdaN_temp[jj,ss] for ss in 1:ns)*(ysp[jj] - ysp_nonⁱ[jj]) for jj in 1:Δdrto))
                #@info "we are adding this bender optimality cut $(benderscutO)"
                
                # optimality cut was add
                flagO = 1
            
            end # if gap
        else # sum(flag_temp) != nScen
            ###############################
            # --> adding feasibility cuts #
            ###############################
            display(">>>>>> iteration $(ii):F")
            benderscutF = @constraint(master, 0 ≥
                sum(sum(lambdaN_temp[jj,ss] for ss in 1:ns)*(ysp[1,jj] - ysp_nonⁱ[1,jj]) for jj in 1:Δdrto))
            #@info "we are adding this bender feasibility cut $(benderscutF)"
            
            # feasibility cut was add
            flagO = 0
            
        end # if nScen
        
        # checking if number of iterations reached max 
        if ii < benIterMax
            global yspSol_dec = [NaN for kk=1:Δdrto]
            global objFun_dec = NaN
            global optGap_dec = NaN
            global iter_dec = benIterMax
            global time_dec = timeSolBen
            global time_max_dec = timeSolParBen
        end # if < benIterMax
    end # if for benders iterations

    #####################
    # Extracting values #
    #####################
    if isnan(objFun_dec)
        
        outputFun = Dict('f' => 0, 
                         't' => timeSolBen,
                         'ϕ' => objFun_dec,
                         'τ' => time_max_dec, 
                         'i' => iter_dec,
                         'd' => yspSol_dec,
                         'g' => optGap_dec,
                         'o' => optGapArray)
                        
        
        return outputFun
        
    else
        CinArray = Matrix{Float64}(undef,ndrto,ns)
        PArray = Array{Float64}(undef,nfe,ncp,ns)
        CArray = Array{Float64}(undef,nfe,ncp,ns)
        yspArray = Matrix{Float64}(undef,ndrto,ns)

        for ss in 1:ns
            dicTemp = subp(yspSol_dec,C_0,P_0,u_0,xMPC_0,de_0,VmTemp[ss],pScen,solNom)

            # saving files
            CinArray[:,ss] = dicTemp['I']
            PArray[:,:,ss] = dicTemp['P']
            CArray[:,:,ss] = dicTemp['C']
            yspArray[:,ss] = dicTemp['s']
        end

        #calling values of the solved problem    
        outputFun =  Dict('f' => 1,
                    'ϕ' => objFun_dec,
                    't' => time_dec,
                    'τ' => time_max_dec, 
                    'i' => iter_dec,
                    'd' => yspSol_dec,
                    'g' => optGap_dec,
                    'I' => CinArray,
                    'P' => PArray,
                    'C' => CArray,
                    's' => yspArray,
                    'o' => optGapArray)  
        
        return outputFun

    end
end;

# %% [markdown]
# <a id="subsec25"></a>

# %% [markdown]
# ## Plant Model

# %%
function bioreactor_ode!(dx, x, p, t)
    C,P = x
    Cin,Vm_plant = p
    
    # Immobilized enzyme or cell catalytic reaction rate (defined by Michaelis-Menten equation)
    rc = Vm_plant*C/(Ks + C)
    
    # reactor 1
    dx[1] = D*(Cin - C) - rc
    dx[2] = rc - D*P
    
    nothing
end;

# %% [markdown]
# <a id="sec3"></a>

# %% [markdown]
# # Implementing CL-DRTO in closed loop with the plant
#
# Here we run a Monte Carlo Analysis of the CL-DRTO results. The uncertain parameter value is drawn at each MC iteration and the DRTO has access to the lower and upper bound of that distribution to create the scenarios.

# %% [markdown]
# Getting the solution for the nominal scenario

# %%
# building MPC's
mpc = MPC_matrices(A,B,C,p,m,q,r);

# %%
# Monte Carlo iterations (20)
n_MC = 20

# Simulation time in sampling periods
nsim = 20

# number of scenarios
nS_MC = 3 

# creating uncertain parameter array
pUnc = LinRange(pNom - deltaPar,pNom + deltaPar, nS_MC)

#equiprobable scenarios
pS_MC = 1.0/nS_MC

# Extracting solution for plotting --> monolithic vs. decomposed 
PPlant = Array{Float64}(undef,nsim,n_MC,2)
CPlant = Array{Float64}(undef,nsim,n_MC,2)
CinPlant = Array{Float64}(undef,nsim,n_MC,2)
yspPlant = Array{Float64}(undef,nsim,n_MC,2)
flagCLDRTO = Array{Float64}(undef,nsim,n_MC,2);

# %% [markdown]
# ## Plant simulation

# %%
for jj = 1:n_MC
    # ramdonly drawing the plant from the previously computed models
    d = Truncated(Normal(pNom, deltaPar), pNom - deltaPar, pNom + deltaPar)  #Construct the distribution type
    pPlant = rand(d)
    display("DB: MC iter. $(jj) --> Plant parameter = $(pPlant)")
    
    # RUNNING SIMULATION
    for mm = 1:2
        
        # preparing simulation (starting from opt steady-state)
        # plant 
        xk = x0
        uk_1 = u0

        # mpc's models - initial states is the same
        xk_mpc = x0 - xref
        dek_mpc = 0.0
        
        # initial conditions (CLDRTO)
        Cpk = C0
        Ppk = P0
        
        solNom = MS_CLDRTO(Cpk,Ppk,uk_1,xk_mpc,dek_mpc,pNom,1,0)
        # checking if 1s solution converged
        if solNom['f'] == 1
            display("Nominal solution at t = 0: found")
        else
           display("DB: Nominal solution at t = 0: not found")
        end
        
        for ii = 1:nsim

            print("MC: ", jj)
            println(">> Time: ",ii)

            # updating arrays # States (algebraic and differential): CA1,CB1,CC1,T1,Tj1_out,CA2,CB2,CC2,T2,Tj2_out
            CPlant[ii,jj,mm] = Cpk
            PPlant[ii,jj,mm] = Ppk
            CinPlant[ii,jj,mm] = uk_1

            # executing DRTO
            if ii%Δdrto == 0 || ii == 1
                
                if ii > 1
                    sol_1s_temp = MS_CLDRTO(Cpk,Ppk,uk_1,xk_mpc,dek_mpc,pNom,1,solNom) 
                    # checking if 1s solution converged
                    if sol_1s_temp['f'] == 1
                        display("DB: Nominal solution at t = $(ii): found")
                        solNom = sol_1s_temp 
                    else
                        display("DB: Nominal solution t = $(ii): not found")
                    end
                end
                
                if mm == 1
                    sol_temp = MS_CLDRTO(Cpk,Ppk,uk_1,xk_mpc,dek_mpc,pUnc,nS_MC,solNom)
                else
                    sol_temp = BENS_CLDRTO(Cpk,Ppk,uk_1,xk_mpc,dek_mpc,pUnc,nS_MC,solNom)
                end
                
                # checking solution
                if sol_temp['f'] == 1
                    display("DB: CLDRTO method: $(mm) - Solution at t = $(ii): found")
                    # updating the solution
                    global sol_k = sol_temp
                    # counter for DRTO executions
                    global countDRTO = 1;
                    # N.B. need to declare as global due to loop scope
                else
                    display("DB: CLDRTO method: $(mm) - Solution at t = $(ii): not found")
                    # does not update either the solution or the counter 
                end
            end
            
            # saving flag: surrogate for CLDRTO flag
            flagCLDRTO[ii,jj,mm] = countDRTO

            # Preparing controller 
            # building terms of the OF that depend on current information
            yspk = sol_k['s'][countDRTO:(countDRTO + (p - 1)),2] 
            countDRTO += 1 
            #display("DB: setpoint sent to the controller $(yspk)")
            # N.B.:
            # using nominal (center) scenario, but any scenario could be used

            # solving MPC
            sol_mpc = solveMPC(xk_mpc,dek_mpc,uk_1,yspk,u_mpc_lb,u_mpc_ub,xref[2],uref,mpc,p,m)
            #display("DB: input sent to plant $(sol_mpc['u'][1])")
            
            # evolving plant
            ode_prob = ODEProblem(bioreactor_ode!,xk,tspan,[sol_mpc['u'][1],pPlant]);
            sol_plant = solve(ode_prob,Tsit5(),reltol=1e-8,abstol=1e-8,save_everystep = false); 
            
            # loop
            # -> Plant 
            xk = sol_plant.u[end]
            uk_1 = sol_mpc['u'][1]
            
            # -> for initializing DRTO
            Cpk = xk[1]
            Ppk = xk[2]
            
            # -> MPCs
            # evolving MPC models
            xk_mpc  = A*xk_mpc + B*(uk_1 - uref)
            dek_mpc = Ppk - (xk_mpc[2] + xref[2])
            
            # saving CLDRTO decisions
            yspPlant[ii,jj,mm] = yspk[1]
            
        end # simulation
    end # monolithic || decomposed
end # MC
# Out:
# "DB: MC iter. 1 --> Plant parameter = 0.8682533402406438"
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
# "Nominal solution at t = 0: found"
# MC: 1>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 1>> Time: 2
# MC: 1>> Time: 3
# MC: 1>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 1>> Time: 5
# MC: 1>> Time: 6
# MC: 1>> Time: 7
# MC: 1>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 1>> Time: 9
# MC: 1>> Time: 10
# MC: 1>> Time: 11
# MC: 1>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 1>> Time: 13
# MC: 1>> Time: 14
# MC: 1>> Time: 15
# MC: 1>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 1>> Time: 17
# MC: 1>> Time: 18
# MC: 1>> Time: 19
# MC: 1>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 1>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.8130866386251648e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 1>> Time: 2
# MC: 1>> Time: 3
# MC: 1>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.000000031197676"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.02377354974069622"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.01979286243900187"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.00014914634552410657"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 1>> Time: 5
# MC: 1>> Time: 6
# MC: 1>> Time: 7
# MC: 1>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.0000000189540053"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.005170998904376881"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004677861669896718"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 1.3008406845075922e-5"
# "DB: CLDRTO method: 2 - Solution at t = 8: found"
# MC: 1>> Time: 9
# MC: 1>> Time: 10
# MC: 1>> Time: 11
# MC: 1>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.000000003080828"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.10724567643666044"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.0402603395942142"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.00035383718130827934"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 1>> Time: 13
# MC: 1>> Time: 14
# MC: 1>> Time: 15
# MC: 1>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.0000000036161802"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004148607916026197"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.0025974874689932087"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.000649306438540024"
# "DB: CLDRTO method: 2 - Solution at t = 16: found"
# MC: 1>> Time: 17
# MC: 1>> Time: 18
# MC: 1>> Time: 19
# MC: 1>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.0000000056966665"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.08500272782641503"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.037242237423291844"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.005806977648073654"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.006053479801715906"
# ">>>>>> iteration 5:O"
# "DB: random"
# "DB: opt. gap 0.007132304265225875"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.0036511424082870726"
# ">>>>>> iteration 7:O"
# "DB: opt. gap 0.0003832119271053571"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"
# "DB: MC iter. 2 --> Plant parameter = 0.8144409547457928"
# "Nominal solution at t = 0: found"
# MC: 2>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 2>> Time: 2
# MC: 2>> Time: 3
# MC: 2>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 2>> Time: 5
# MC: 2>> Time: 6
# MC: 2>> Time: 7
# MC: 2>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 2>> Time: 9
# MC: 2>> Time: 10
# MC: 2>> Time: 11
# MC: 2>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 2>> Time: 13
# MC: 2>> Time: 14
# MC: 2>> Time: 15
# MC: 2>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 2>> Time: 17
# MC: 2>> Time: 18
# MC: 2>> Time: 19
# MC: 2>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 2>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.811572433666845e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 2>> Time: 2
# MC: 2>> Time: 3
# MC: 2>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.0000000302296586"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.022535027637713586"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.018412244062412413"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.00013542289338068324"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 2>> Time: 5
# MC: 2>> Time: 6
# MC: 2>> Time: 7
# MC: 2>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.0000001360735147"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.06570347805590322"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.021173814534332022"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.008414112060055079"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.011636542499765949"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.0006889833306377647"
# "DB: CLDRTO method: 2 - Solution at t = 8: found"
# MC: 2>> Time: 9
# MC: 2>> Time: 10
# MC: 2>> Time: 11
# MC: 2>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.0000000038601453"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.1167664762229689"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.04820817864072484"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.015175618935774635"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.007624151737942731"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.0011858843341270866"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 3.516883452426962e-5"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 2>> Time: 13
# MC: 2>> Time: 14
# MC: 2>> Time: 15
# MC: 2>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.0000000089722971"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.3467717532237891"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.1354859291746005"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.04467444568574261"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.012873667434708504"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.013483174573210473"
# ">>>>>> iteration 6:O"
# "DB: random"
# "DB: opt. gap 0.004434296412983512"
# ">>>>>> iteration 7:O"
# "DB: opt. gap 0.0010965256584747748"
# ">>>>>> iteration 8:O"
# "DB: opt. gap 0.0002735285404148364"
# "DB: CLDRTO method: 2 - Solution at t = 16: found"
# MC: 2>> Time: 17
# MC: 2>> Time: 18
# MC: 2>> Time: 19
# MC: 2>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.0000000084955605"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.011617161536515062"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.0038264629152304393"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0009516416866150285"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"
# "DB: MC iter. 3 --> Plant parameter = 0.7934682591656332"
# "Nominal solution at t = 0: found"
# MC: 3>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 3>> Time: 2
# MC: 3>> Time: 3
# MC: 3>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 3>> Time: 5
# MC: 3>> Time: 6
# MC: 3>> Time: 7
# MC: 3>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 3>> Time: 9
# MC: 3>> Time: 10
# MC: 3>> Time: 11
# MC: 3>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 3>> Time: 13
# MC: 3>> Time: 14
# MC: 3>> Time: 15
# MC: 3>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 3>> Time: 17
# MC: 3>> Time: 18
# MC: 3>> Time: 19
# MC: 3>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 3>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.8131214320715595e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 3>> Time: 2
# MC: 3>> Time: 3
# MC: 3>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.0000000294569065"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.01683616038411827"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.01571545548499398"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 1.9664974339179674e-5"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 3>> Time: 5
# MC: 3>> Time: 6
# MC: 3>> Time: 7
# MC: 3>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.0000005416136801"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.12369768589667138"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.04442565154501519"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.00898841221673313"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.002407149036173772"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.0005984415429605015"
# "DB: CLDRTO method: 2 - Solution at t = 8: found"
# MC: 3>> Time: 9
# MC: 3>> Time: 10
# MC: 3>> Time: 11
# MC: 3>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.000000005045192"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.1119035548295147"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.04732903667627522"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.01597169633274812"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.016938298741581367"
# ">>>>>> iteration 5:O"
# "DB: random"
# "DB: opt. gap 0.00990636790184364"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.0031718605148733548"
# ">>>>>> iteration 7:O"
# "DB: opt. gap 0.00043940950623399687"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 3>> Time: 13
# MC: 3>> Time: 14
# MC: 3>> Time: 15
# MC: 3>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.0000000100786706"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.0964639468949752"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.09646394572688259"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 0.09646394493566057"
# ">>>>>> iteration 4:O"
# "DB: random"
# "DB: opt. gap 0.09646394326461669"
# ">>>>>> iteration 5:O"
# "DB: random"
# "DB: opt. gap 0.09646394196946734"
# ">>>>>> iteration 6:O"
# "DB: random"
# "DB: opt. gap 0.09646394057013048"
# ">>>>>> iteration 7:O"
# "DB: random"
# "DB: opt. gap 0.09646393922617509"
# ">>>>>> iteration 8:O"
# "DB: random"
# "DB: opt. gap 0.09646393775932416"
# ">>>>>> iteration 9:O"
# "DB: random"
# "DB: opt. gap 0.09646393620388843"
# ">>>>>> iteration 10:O"
# "DB: random"
# "DB: opt. gap 0.09646393452655545"
# ">>>>>> iteration 11:O"
# "DB: random"
# "DB: opt. gap 0.09646404890403062"
# ">>>>>> iteration 12:O"
# "DB: random"
# "DB: opt. gap 0.09646404677782347"
# ">>>>>> iteration 13:O"
# "DB: random"
# "DB: opt. gap 0.09646404406926691"
# ">>>>>> iteration 14:O"
# "DB: random"
# "DB: opt. gap 0.09646394663937485"
# ">>>>>> iteration 15:O"
# "DB: random"
# "DB: opt. gap 0.09646394663937954"
# ">>>>>> iteration 16:O"
# "DB: random"
# "DB: opt. gap 0.09646394663938077"
# ">>>>>> iteration 17:O"
# "DB: random"
# "DB: opt. gap 0.096463946639382"
# ">>>>>> iteration 18:O"
# "DB: random"
# "DB: opt. gap 0.09646394663938222"
# ">>>>>> iteration 19:O"
# "DB: random"
# "DB: opt. gap 0.09646394663938652"
# ">>>>>> iteration 20:O"
# "DB: random"
# "DB: opt. gap 0.09646394663939323"
# ">>>>>> iteration 21:O"
# "DB: random"
# "DB: opt. gap 0.09646394663939449"
# ">>>>>> iteration 22:O"
# "DB: random"
# "DB: opt. gap 0.09646394663939531"
# ">>>>>> iteration 23:O"
# "DB: random"
# "DB: opt. gap 0.09646394663939716"
# ">>>>>> iteration 24:O"
# "DB: random"
# "DB: opt. gap 0.09646394663939556"
# ">>>>>> iteration 25:O"
# "DB: random"
# "DB: opt. gap 0.09646394663939961"
# ">>>>>> iteration 26:O"
# "DB: random"
# "DB: opt. gap 0.09646394663940391"
# ">>>>>> iteration 27:O"
# "DB: random"
# "DB: opt. gap 0.09646394663940802"
# ">>>>>> iteration 28:O"
# "DB: random"
# "DB: opt. gap 0.09646394663941044"
# ">>>>>> iteration 29:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394107"
# ">>>>>> iteration 30:O"
# "DB: random"
# "DB: opt. gap 0.09646394663941132"
# ">>>>>> iteration 31:O"
# "DB: random"
# "DB: opt. gap 0.09646394663941787"
# ">>>>>> iteration 32:O"
# "DB: random"
# "DB: opt. gap 0.09646394663941955"
# ">>>>>> iteration 33:O"
# "DB: random"
# "DB: opt. gap 0.09646394663941915"
# ">>>>>> iteration 34:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394227"
# ">>>>>> iteration 35:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394249"
# ">>>>>> iteration 36:O"
# "DB: random"
# "DB: opt. gap 0.09646394663942655"
# ">>>>>> iteration 37:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394276"
# ">>>>>> iteration 38:O"
# "DB: random"
# "DB: opt. gap 0.09646394663942903"
# ">>>>>> iteration 39:O"
# "DB: random"
# "DB: opt. gap 0.09646394663943335"
# ">>>>>> iteration 40:O"
# "DB: random"
# "DB: opt. gap 0.09646394663943564"
# ">>>>>> iteration 41:O"
# "DB: random"
# "DB: opt. gap 0.09646394663943832"
# ">>>>>> iteration 42:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394432"
# ">>>>>> iteration 43:O"
# "DB: random"
# "DB: opt. gap 0.09646394663944494"
# ">>>>>> iteration 44:O"
# "DB: random"
# "DB: opt. gap 0.09646394663944491"
# ">>>>>> iteration 45:O"
# "DB: random"
# "DB: opt. gap 0.09646394663944521"
# ">>>>>> iteration 46:O"
# "DB: random"
# "DB: opt. gap 0.09646394663944585"
# ">>>>>> iteration 47:O"
# "DB: random"
# "DB: opt. gap 0.09646394663945013"
# ">>>>>> iteration 48:O"
# "DB: random"
# "DB: opt. gap 0.09646394663945183"
# ">>>>>> iteration 49:O"
# "DB: random"
# "DB: opt. gap 0.09646394663945349"
# ">>>>>> iteration 50:O"
# "DB: random"
# "DB: opt. gap 0.09646394663945536"
# ">>>>>> iteration 51:O"
# "DB: random"
# "DB: opt. gap 0.09646394663945886"
# ">>>>>> iteration 52:O"
# "DB: random"
# "DB: opt. gap 0.09646394663946298"
# ">>>>>> iteration 53:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394624"
# ">>>>>> iteration 54:O"
# "DB: random"
# "DB: opt. gap 0.09646394663946209"
# ">>>>>> iteration 55:O"
# "DB: random"
# "DB: opt. gap 0.09646394663946375"
# ">>>>>> iteration 56:O"
# "DB: random"
# "DB: opt. gap 0.09646394663946664"
# ">>>>>> iteration 57:O"
# "DB: random"
# "DB: opt. gap 0.09646394663947097"
# ">>>>>> iteration 58:O"
# "DB: random"
# "DB: opt. gap 0.09646394663947756"
# ">>>>>> iteration 59:O"
# "DB: random"
# "DB: opt. gap 0.09646394663947491"
# ">>>>>> iteration 60:O"
# "DB: random"
# "DB: opt. gap 0.096463946639477"
# ">>>>>> iteration 61:O"
# "DB: random"
# "DB: opt. gap 0.09646394663948114"
# ">>>>>> iteration 62:O"
# "DB: random"
# "DB: opt. gap 0.09646394663948057"
# ">>>>>> iteration 63:O"
# "DB: random"
# "DB: opt. gap 0.09646394663948366"
# ">>>>>> iteration 64:O"
# "DB: random"
# "DB: opt. gap 0.09646394663948751"
# ">>>>>> iteration 65:O"
# "DB: random"
# "DB: opt. gap 0.09646394663948657"
# ">>>>>> iteration 66:O"
# "DB: random"
# "DB: opt. gap 0.09646394663948622"
# ">>>>>> iteration 67:O"
# "DB: random"
# "DB: opt. gap 0.09646394663949155"
# ">>>>>> iteration 68:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394933"
# ">>>>>> iteration 69:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394939"
# ">>>>>> iteration 70:O"
# "DB: random"
# "DB: opt. gap 0.09646394663949194"
# ">>>>>> iteration 71:O"
# "DB: random"
# "DB: opt. gap 0.09646394663950536"
# ">>>>>> iteration 72:O"
# "DB: random"
# "DB: opt. gap 0.0964639466394975"
# ">>>>>> iteration 73:O"
# "DB: random"
# "DB: opt. gap 0.09646394663950765"
# ">>>>>> iteration 74:O"
# "DB: random"
# "DB: opt. gap 0.09646394663950085"
# ">>>>>> iteration 75:O"
# "DB: random"
# "DB: opt. gap 0.09646394663950313"
# ">>>>>> iteration 76:O"
# "DB: random"
# "DB: opt. gap 0.09646394663950765"
# ">>>>>> iteration 77:O"
# "DB: random"
# "DB: opt. gap 0.09646394663951162"
# ">>>>>> iteration 78:O"
# "DB: random"
# "DB: opt. gap 0.09646394663951777"
# ">>>>>> iteration 79:O"
# "DB: random"
# "DB: opt. gap 0.09646394663951599"
# ">>>>>> iteration 80:O"
# "DB: random"
# "DB: opt. gap 0.09646394663951166"
# ">>>>>> iteration 81:O"
# "DB: random"
# "DB: opt. gap 0.09646394663952411"
# ">>>>>> iteration 82:O"
# "DB: random"
# "DB: opt. gap 0.09646394663953212"
# ">>>>>> iteration 83:O"
# "DB: random"
# "DB: opt. gap 0.09646394663952394"
# ">>>>>> iteration 84:O"
# "DB: random"
# "DB: opt. gap 0.09646394663952844"
# ">>>>>> iteration 85:O"
# "DB: random"
# "DB: opt. gap 0.09646394663953015"
# ">>>>>> iteration 86:O"
# "DB: random"
# "DB: opt. gap 0.09646394663953248"
# ">>>>>> iteration 87:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395376"
# ">>>>>> iteration 88:O"
# "DB: random"
# "DB: opt. gap 0.09646394663953986"
# ">>>>>> iteration 89:O"
# "DB: random"
# "DB: opt. gap 0.09646394663953752"
# ">>>>>> iteration 90:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395396"
# ">>>>>> iteration 91:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395413"
# ">>>>>> iteration 92:O"
# "DB: random"
# "DB: opt. gap 0.09646394663954196"
# ">>>>>> iteration 93:O"
# "DB: random"
# "DB: opt. gap 0.09646394663954812"
# ">>>>>> iteration 94:O"
# "DB: random"
# "DB: opt. gap 0.09646394663954963"
# ">>>>>> iteration 95:O"
# "DB: random"
# "DB: opt. gap 0.09646394663955297"
# ">>>>>> iteration 96:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395514"
# ">>>>>> iteration 97:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395529"
# ">>>>>> iteration 98:O"
# "DB: random"
# "DB: opt. gap 0.096463946639558"
# ">>>>>> iteration 99:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395557"
# ">>>>>> iteration 100:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395588"
# ">>>>>> iteration 101:O"
# "DB: random"
# "DB: opt. gap 0.09646394663956132"
# ">>>>>> iteration 102:O"
# "DB: random"
# "DB: opt. gap 0.09646394663956162"
# ">>>>>> iteration 103:O"
# "DB: random"
# "DB: opt. gap 0.09646394663956655"
# ">>>>>> iteration 104:O"
# "DB: random"
# "DB: opt. gap 0.09646394663956397"
# ">>>>>> iteration 105:O"
# "DB: random"
# "DB: opt. gap 0.09646394663956871"
# ">>>>>> iteration 106:O"
# "DB: random"
# "DB: opt. gap 0.09646394663957429"
# ">>>>>> iteration 107:O"
# "DB: random"
# "DB: opt. gap 0.09646394663957468"
# ">>>>>> iteration 108:O"
# "DB: random"
# "DB: opt. gap 0.09646394663957485"
# ">>>>>> iteration 109:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395755"
# ">>>>>> iteration 110:O"
# "DB: random"
# "DB: opt. gap 0.09646394663957722"
# ">>>>>> iteration 111:O"
# "DB: random"
# "DB: opt. gap 0.0964639466395893"
# ">>>>>> iteration 112:O"
# "DB: random"
# "DB: opt. gap 0.09646394663957984"
# ">>>>>> iteration 113:O"
# "DB: random"
# "DB: opt. gap 0.09646394663958152"
# ">>>>>> iteration 114:O"
# "DB: random"
# "DB: opt. gap 0.09646394663958366"
# ">>>>>> iteration 115:O"
# "DB: random"
# "DB: opt. gap 0.09646394663958738"
# ">>>>>> iteration 116:O"
# "DB: random"
# "DB: opt. gap 0.09646394663958581"
# ">>>>>> iteration 117:O"
# "DB: random"
# "DB: opt. gap 0.09646394663958772"
# ">>>>>> iteration 118:O"
# "DB: random"
# "DB: opt. gap 0.09646394663960807"
# ">>>>>> iteration 119:O"
# "DB: random"
# "DB: opt. gap 0.09646394663959278"
# ">>>>>> iteration 120:O"
# "DB: random"
# "DB: opt. gap 0.09646394663959407"
# ">>>>>> iteration 121:O"
# "DB: random"
# "DB: opt. gap 0.09646394663959659"
# ">>>>>> iteration 122:O"
# "DB: random"
# "DB: opt. gap 0.09646394663959729"
# ">>>>>> iteration 123:O"
# "DB: random"
# "DB: opt. gap 0.09646394663959919"
# ">>>>>> iteration 124:O"
# "DB: random"
# "DB: opt. gap 0.09646394663960058"
# ">>>>>> iteration 125:O"
# "DB: random"
# "DB: opt. gap 0.09646394663960343"
# ">>>>>> iteration 126:O"
# "DB: random"
# "DB: opt. gap 0.09646394663961431"
# ">>>>>> iteration 127:O"
# "DB: random"
# "DB: opt. gap 0.09646394663960543"
# ">>>>>> iteration 128:O"
# "DB: random"
# "DB: opt. gap 0.09646394663960811"
# ">>>>>> iteration 129:O"
# "DB: random"
# "DB: opt. gap 0.09646394663962087"
# ">>>>>> iteration 130:O"
# "DB: random"
# "DB: opt. gap 0.0964639466396241"
# ">>>>>> iteration 131:O"
# "DB: random"
# "DB: opt. gap 0.09646394663961165"
# ">>>>>> iteration 132:O"
# "DB: random"
# "DB: opt. gap 0.09646394663962383"
# ">>>>>> iteration 133:O"
# "DB: random"
# "DB: opt. gap 0.09646394663961969"
# ">>>>>> iteration 134:O"
# "DB: random"
# "DB: opt. gap 0.09646394663963945"
# ">>>>>> iteration 135:O"
# "DB: random"
# "DB: opt. gap 0.09646394663962024"
# ">>>>>> iteration 136:O"
# "DB: random"
# "DB: opt. gap 0.09646394663962234"
# ">>>>>> iteration 137:O"
# "DB: random"
# "DB: opt. gap 0.09646394663963509"
# ">>>>>> iteration 138:O"
# "DB: random"
# "DB: opt. gap 0.09646394663962674"
# ">>>>>> iteration 139:O"
# "DB: random"
# "DB: opt. gap 0.09646394663963795"
# ">>>>>> iteration 140:O"
# "DB: random"
# "DB: opt. gap 0.09646394663962661"
# ">>>>>> iteration 141:O"
# "DB: random"
# "DB: opt. gap 0.09646394663962869"
# ">>>>>> iteration 142:O"
# "DB: random"
# "DB: opt. gap 0.09646394663963424"
# ">>>>>> iteration 143:O"
# "DB: random"
# "DB: opt. gap 0.09646394663964121"
# ">>>>>> iteration 144:O"
# "DB: random"
# "DB: opt. gap 0.09646394663963243"
# ">>>>>> iteration 145:O"
# "DB: random"
# "DB: opt. gap 0.09646394663963172"
# ">>>>>> iteration 146:O"
# "DB: random"
# "DB: opt. gap 0.0964639466396328"
# ">>>>>> iteration 147:O"
# "DB: random"
# "DB: opt. gap 0.0964639466396645"
# ">>>>>> iteration 148:O"
# "DB: random"
# "DB: opt. gap 0.09646394663967368"
# ">>>>>> iteration 149:O"
# "DB: random"
# "DB: opt. gap 0.0964639466396427"
# ">>>>>> iteration 150:O"
# "DB: CLDRTO method: 2 - Solution at t = 16: not found"
# MC: 3>> Time: 17
# MC: 3>> Time: 18
# MC: 3>> Time: 19
# MC: 3>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.0000000038803747"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.07986777788936042"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.029616886830365428"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.011694546544456948"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.01560213114467707"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.008567254894075565"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.001847146295578786"
# ">>>>>> iteration 7:O"
# "DB: opt. gap 6.458065821045293e-5"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"
# "DB: MC iter. 4 --> Plant parameter = 0.8723818263230854"
# "Nominal solution at t = 0: found"
# MC: 4>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 4>> Time: 2
# MC: 4>> Time: 3
# MC: 4>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 4>> Time: 5
# MC: 4>> Time: 6
# MC: 4>> Time: 7
# MC: 4>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 4>> Time: 9
# MC: 4>> Time: 10
# MC: 4>> Time: 11
# MC: 4>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 4>> Time: 13
# MC: 4>> Time: 14
# MC: 4>> Time: 15
# MC: 4>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 4>> Time: 17
# MC: 4>> Time: 18
# MC: 4>> Time: 19
# MC: 4>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 4>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.81328497610281e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 4>> Time: 2
# MC: 4>> Time: 3
# MC: 4>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.000000031211602"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.024039109357517668"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.02001925717826552"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.00015303172589207343"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 4>> Time: 5
# MC: 4>> Time: 6
# MC: 4>> Time: 7
# MC: 4>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.000000017342108"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.00520036386484529"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004713172241092318"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 1.4171948934827018e-5"
# "DB: CLDRTO method: 2 - Solution at t = 8: found"
# MC: 4>> Time: 9
# MC: 4>> Time: 10
# MC: 4>> Time: 11
# MC: 4>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.000000003021358"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.10119194051661473"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.05966833109305743"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0007910936876521827"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 4>> Time: 13
# MC: 4>> Time: 14
# MC: 4>> Time: 15
# MC: 4>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.0000000034715426"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.0037824910492657315"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.002406504658689363"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0005958007620964314"
# "DB: CLDRTO method: 2 - Solution at t = 16: found"
# MC: 4>> Time: 17
# MC: 4>> Time: 18
# MC: 4>> Time: 19
# MC: 4>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.0000000055546754"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.08367271880086591"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.032429768154598845"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.004831386154972768"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.005129821067425105"
# ">>>>>> iteration 5:O"
# "DB: random"
# "DB: opt. gap 7.613818153449509e-5"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"
# "DB: MC iter. 5 --> Plant parameter = 0.6755367315855255"
# "Nominal solution at t = 0: found"
# MC: 5>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 5>> Time: 2
# MC: 5>> Time: 3
# MC: 5>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 5>> Time: 5
# MC: 5>> Time: 6
# MC: 5>> Time: 7
# MC: 5>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 5>> Time: 9
# MC: 5>> Time: 10
# MC: 5>> Time: 11
# MC: 5>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 5>> Time: 13
# MC: 5>> Time: 14
# MC: 5>> Time: 15
# MC: 5>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 5>> Time: 17
# MC: 5>> Time: 18
# MC: 5>> Time: 19
# MC: 5>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 5>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.8131871539819046e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 5>> Time: 2
# MC: 5>> Time: 3
# MC: 5>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.000000022693688"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.0074586499067681045"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.006407874983912986"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 3.044776634907945e-5"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 5>> Time: 5
# MC: 5>> Time: 6
# MC: 5>> Time: 7
# MC: 5>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.0000000725038638"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 36.17783591264224"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 36.177835707273964"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 36.17783551282647"
# ">>>>>> iteration 4:O"
# "DB: random"
# "DB: opt. gap 36.17783548124279"
# ">>>>>> iteration 5:O"
# "DB: random"
# "DB: opt. gap 36.177835405877474"
# ">>>>>> iteration 6:O"
# "DB: random"
# "DB: opt. gap 36.1778352359102"
# ">>>>>> iteration 7:O"
# "DB: random"
# "DB: opt. gap 36.1778350616509"
# ">>>>>> iteration 8:O"
# "DB: random"
# "DB: opt. gap 36.17783488249338"
# ">>>>>> iteration 9:O"
# "DB: random"
# "DB: opt. gap 36.17783469764751"
# ">>>>>> iteration 10:O"
# "DB: random"
# "DB: opt. gap 36.17783450600881"
# ">>>>>> iteration 11:O"
# "DB: random"
# "DB: opt. gap 36.17783430657142"
# ">>>>>> iteration 12:O"
# "DB: random"
# "DB: opt. gap 36.1778340971678"
# ">>>>>> iteration 13:O"
# "DB: random"
# "DB: opt. gap 36.17783387525282"
# ">>>>>> iteration 14:O"
# "DB: random"
# "DB: opt. gap 36.17783363686056"
# ">>>>>> iteration 15:O"
# "DB: random"
# "DB: opt. gap 36.177833375171126"
# ">>>>>> iteration 16:O"
# "DB: random"
# "DB: opt. gap 36.17783307735072"
# ">>>>>> iteration 17:O"
# "DB: random"
# "DB: opt. gap 36.17787698004053"
# ">>>>>> iteration 18:O"
# "DB: random"
# "DB: opt. gap 36.17783599366247"
# ">>>>>> iteration 19:O"
# "DB: random"
# "DB: opt. gap 36.17783599366275"
# ">>>>>> iteration 20:O"
# "DB: random"
# "DB: opt. gap 36.17783599366313"
# ">>>>>> iteration 21:O"
# "DB: random"
# "DB: opt. gap 36.17783599366342"
# ">>>>>> iteration 22:O"
# "DB: random"
# "DB: opt. gap 36.177835993663784"
# ">>>>>> iteration 23:O"
# "DB: random"
# "DB: opt. gap 36.17783599366406"
# ">>>>>> iteration 24:O"
# "DB: random"
# "DB: opt. gap 36.17783599366445"
# ">>>>>> iteration 25:O"
# "DB: random"
# "DB: opt. gap 36.177835993664715"
# ">>>>>> iteration 26:O"
# "DB: random"
# "DB: opt. gap 36.177835993665035"
# ">>>>>> iteration 27:O"
# "DB: random"
# "DB: opt. gap 36.1778359936654"
# ">>>>>> iteration 28:O"
# "DB: random"
# "DB: opt. gap 36.177835993665724"
# ">>>>>> iteration 29:O"
# "DB: random"
# "DB: opt. gap 36.17783599366601"
# ">>>>>> iteration 30:O"
# "DB: random"
# "DB: opt. gap 36.177835993666285"
# ">>>>>> iteration 31:O"
# "DB: random"
# "DB: opt. gap 36.17783599366665"
# ">>>>>> iteration 32:O"
# "DB: random"
# "DB: opt. gap 36.17783599366696"
# ">>>>>> iteration 33:O"
# "DB: random"
# "DB: opt. gap 36.17783599366728"
# ">>>>>> iteration 34:O"
# "DB: random"
# "DB: opt. gap 36.17783599366762"
# ">>>>>> iteration 35:O"
# "DB: random"
# "DB: opt. gap 36.177835993668005"
# ">>>>>> iteration 36:O"
# "DB: random"
# "DB: opt. gap 36.17783599366827"
# ">>>>>> iteration 37:O"
# "DB: random"
# "DB: opt. gap 36.17783599366852"
# ">>>>>> iteration 38:O"
# "DB: random"
# "DB: opt. gap 36.17783599366885"
# ">>>>>> iteration 39:O"
# "DB: random"
# "DB: opt. gap 36.1778359936692"
# ">>>>>> iteration 40:O"
# "DB: random"
# "DB: opt. gap 36.177835993669476"
# ">>>>>> iteration 41:O"
# "DB: random"
# "DB: opt. gap 36.177835993669824"
# ">>>>>> iteration 42:O"
# "DB: random"
# "DB: opt. gap 36.17783599367013"
# ">>>>>> iteration 43:O"
# "DB: random"
# "DB: opt. gap 36.1778359936705"
# ">>>>>> iteration 44:O"
# "DB: random"
# "DB: opt. gap 36.177835993670804"
# ">>>>>> iteration 45:O"
# "DB: random"
# "DB: opt. gap 36.17783599367107"
# ">>>>>> iteration 46:O"
# "DB: random"
# "DB: opt. gap 36.17783599367143"
# ">>>>>> iteration 47:O"
# "DB: random"
# "DB: opt. gap 36.177835993671735"
# ">>>>>> iteration 48:O"
# "DB: random"
# "DB: opt. gap 36.177835993672005"
# ">>>>>> iteration 49:O"
# "DB: random"
# "DB: opt. gap 36.177835993672424"
# ">>>>>> iteration 50:O"
# "DB: random"
# "DB: opt. gap 36.17783599367283"
# ">>>>>> iteration 51:O"
# "DB: random"
# "DB: opt. gap 36.177835993673"
# ">>>>>> iteration 52:O"
# "DB: random"
# "DB: opt. gap 36.17783599367346"
# ">>>>>> iteration 53:O"
# "DB: random"
# "DB: opt. gap 36.1778359936737"
# ">>>>>> iteration 54:O"
# "DB: random"
# "DB: opt. gap 36.177835993674016"
# ">>>>>> iteration 55:O"
# "DB: random"
# "DB: opt. gap 36.17783599367435"
# ">>>>>> iteration 56:O"
# "DB: random"
# "DB: opt. gap 36.1778359936746"
# ">>>>>> iteration 57:O"
# "DB: random"
# "DB: opt. gap 36.177835993674925"
# ">>>>>> iteration 58:O"
# "DB: random"
# "DB: opt. gap 36.177835993675224"
# ">>>>>> iteration 59:O"
# "DB: random"
# "DB: opt. gap 36.17783599367558"
# ">>>>>> iteration 60:O"
# "DB: random"
# "DB: opt. gap 36.17783599367593"
# ">>>>>> iteration 61:O"
# "DB: random"
# "DB: opt. gap 36.17783599367617"
# ">>>>>> iteration 62:O"
# "DB: random"
# "DB: opt. gap 36.17783599367652"
# ">>>>>> iteration 63:O"
# "DB: random"
# "DB: opt. gap 36.17783599367682"
# ">>>>>> iteration 64:O"
# "DB: random"
# "DB: opt. gap 36.177835993677185"
# ">>>>>> iteration 65:O"
# "DB: random"
# "DB: opt. gap 36.177835993677405"
# ">>>>>> iteration 66:O"
# "DB: random"
# "DB: opt. gap 36.17783599367767"
# ">>>>>> iteration 67:O"
# "DB: random"
# "DB: opt. gap 36.17783599367804"
# ">>>>>> iteration 68:O"
# "DB: random"
# "DB: opt. gap 36.177835993678336"
# ">>>>>> iteration 69:O"
# "DB: random"
# "DB: opt. gap 36.17783599367859"
# ">>>>>> iteration 70:O"
# "DB: random"
# "DB: opt. gap 36.17783599367892"
# ">>>>>> iteration 71:O"
# "DB: random"
# "DB: opt. gap 36.17783599367928"
# ">>>>>> iteration 72:O"
# "DB: random"
# "DB: opt. gap 36.17783599367956"
# ">>>>>> iteration 73:O"
# "DB: random"
# "DB: opt. gap 36.17783599367983"
# ">>>>>> iteration 74:O"
# "DB: random"
# "DB: opt. gap 36.17783599368011"
# ">>>>>> iteration 75:O"
# "DB: random"
# "DB: opt. gap 36.17783599368057"
# ">>>>>> iteration 76:O"
# "DB: random"
# "DB: opt. gap 36.17783599368072"
# ">>>>>> iteration 77:O"
# "DB: random"
# "DB: opt. gap 36.17783599368101"
# ">>>>>> iteration 78:O"
# "DB: random"
# "DB: opt. gap 36.177835993681335"
# ">>>>>> iteration 79:O"
# "DB: random"
# "DB: opt. gap 36.177835993681654"
# ">>>>>> iteration 80:O"
# "DB: random"
# "DB: opt. gap 36.17783599368193"
# ">>>>>> iteration 81:O"
# "DB: random"
# "DB: opt. gap 36.17783599368223"
# ">>>>>> iteration 82:O"
# "DB: random"
# "DB: opt. gap 36.17783599368244"
# ">>>>>> iteration 83:O"
# "DB: random"
# "DB: opt. gap 36.177835993682855"
# ">>>>>> iteration 84:O"
# "DB: random"
# "DB: opt. gap 36.17783599368315"
# ">>>>>> iteration 85:O"
# "DB: random"
# "DB: opt. gap 36.177835993683416"
# ">>>>>> iteration 86:O"
# "DB: random"
# "DB: opt. gap 36.17783599368372"
# ">>>>>> iteration 87:O"
# "DB: random"
# "DB: opt. gap 36.177835993684035"
# ">>>>>> iteration 88:O"
# "DB: random"
# "DB: opt. gap 36.17783599368433"
# ">>>>>> iteration 89:O"
# "DB: random"
# "DB: opt. gap 36.17783599368455"
# ">>>>>> iteration 90:O"
# "DB: random"
# "DB: opt. gap 36.17783599368525"
# ">>>>>> iteration 91:O"
# "DB: random"
# "DB: opt. gap 36.17783599368517"
# ">>>>>> iteration 92:O"
# "DB: random"
# "DB: opt. gap 36.177835993685505"
# ">>>>>> iteration 93:O"
# "DB: random"
# "DB: opt. gap 36.17783599368573"
# ">>>>>> iteration 94:O"
# "DB: random"
# "DB: opt. gap 36.17783599368602"
# ">>>>>> iteration 95:O"
# "DB: random"
# "DB: opt. gap 36.17783599368637"
# ">>>>>> iteration 96:O"
# "DB: random"
# "DB: opt. gap 36.177835993686955"
# ">>>>>> iteration 97:O"
# "DB: random"
# "DB: opt. gap 36.17783599368714"
# ">>>>>> iteration 98:O"
# "DB: random"
# "DB: opt. gap 36.177835993687225"
# ">>>>>> iteration 99:O"
# "DB: random"
# "DB: opt. gap 36.17783599368754"
# ">>>>>> iteration 100:O"
# "DB: random"
# "DB: opt. gap 36.17783599368778"
# ">>>>>> iteration 101:O"
# "DB: random"
# "DB: opt. gap 36.177835993688184"
# ">>>>>> iteration 102:O"
# "DB: random"
# "DB: opt. gap 36.17783599368869"
# ">>>>>> iteration 103:O"
# "DB: random"
# "DB: opt. gap 36.177835993688696"
# ">>>>>> iteration 104:O"
# "DB: random"
# "DB: opt. gap 36.17783599368934"
# ">>>>>> iteration 105:O"
# "DB: random"
# "DB: opt. gap 36.17783599368929"
# ">>>>>> iteration 106:O"
# "DB: random"
# "DB: opt. gap 36.1778359936896"
# ">>>>>> iteration 107:O"
# "DB: random"
# "DB: opt. gap 36.17783599368987"
# ">>>>>> iteration 108:O"
# "DB: random"
# "DB: opt. gap 36.17783599369013"
# ">>>>>> iteration 109:O"
# "DB: random"
# "DB: opt. gap 36.17783599369044"
# ">>>>>> iteration 110:O"
# "DB: random"
# "DB: opt. gap 36.1778359936907"
# ">>>>>> iteration 111:O"
# "DB: random"
# "DB: opt. gap 36.17783599369104"
# ">>>>>> iteration 112:O"
# "DB: random"
# "DB: opt. gap 36.17783599369134"
# ">>>>>> iteration 113:O"
# "DB: random"
# "DB: opt. gap 36.17783599369165"
# ">>>>>> iteration 114:O"
# "DB: random"
# "DB: opt. gap 36.17783599369189"
# ">>>>>> iteration 115:O"
# "DB: random"
# "DB: opt. gap 36.177835993692085"
# ">>>>>> iteration 116:O"
# "DB: random"
# "DB: opt. gap 36.177835993692355"
# ">>>>>> iteration 117:O"
# "DB: random"
# "DB: opt. gap 36.17783599369266"
# ">>>>>> iteration 118:O"
# "DB: random"
# "DB: opt. gap 36.17783599369298"
# ">>>>>> iteration 119:O"
# "DB: random"
# "DB: opt. gap 36.177835993693435"
# ">>>>>> iteration 120:O"
# "DB: random"
# "DB: opt. gap 36.17783599369389"
# ">>>>>> iteration 121:O"
# "DB: random"
# "DB: opt. gap 36.177835993694416"
# ">>>>>> iteration 122:O"
# "DB: random"
# "DB: opt. gap 36.17783599369471"
# ">>>>>> iteration 123:O"
# "DB: random"
# "DB: opt. gap 36.17783599369501"
# ">>>>>> iteration 124:O"
# "DB: random"
# "DB: opt. gap 36.17783599369532"
# ">>>>>> iteration 125:O"
# "DB: random"
# "DB: opt. gap 36.17783599369564"
# ">>>>>> iteration 126:O"
# "DB: random"
# "DB: opt. gap 36.17783599369589"
# ">>>>>> iteration 127:O"
# "DB: random"
# "DB: opt. gap 36.1778359936962"
# ">>>>>> iteration 128:O"
# "DB: random"
# "DB: opt. gap 36.17783599369646"
# ">>>>>> iteration 129:O"
# "DB: random"
# "DB: opt. gap 36.177835993696746"
# ">>>>>> iteration 130:O"
# "DB: random"
# "DB: opt. gap 36.17783599369703"
# ">>>>>> iteration 131:O"
# "DB: random"
# "DB: opt. gap 36.177835993697336"
# ">>>>>> iteration 132:O"
# "DB: random"
# "DB: opt. gap 36.177835993697634"
# ">>>>>> iteration 133:O"
# "DB: random"
# "DB: opt. gap 36.177835993697926"
# ">>>>>> iteration 134:O"
# "DB: random"
# "DB: opt. gap 36.177835993698196"
# ">>>>>> iteration 135:O"
# "DB: random"
# "DB: opt. gap 36.177835993698494"
# ">>>>>> iteration 136:O"
# "DB: random"
# "DB: opt. gap 36.17783599369877"
# ">>>>>> iteration 137:O"
# "DB: random"
# "DB: opt. gap 36.17783599369906"
# ">>>>>> iteration 138:O"
# "DB: random"
# "DB: opt. gap 36.17783599369936"
# ">>>>>> iteration 139:O"
# "DB: random"
# "DB: opt. gap 36.177835993699645"
# ">>>>>> iteration 140:O"
# "DB: random"
# "DB: opt. gap 36.17783599369993"
# ">>>>>> iteration 141:O"
# "DB: random"
# "DB: opt. gap 36.17783599370023"
# ">>>>>> iteration 142:O"
# "DB: random"
# "DB: opt. gap 36.177835993700576"
# ">>>>>> iteration 143:O"
# "DB: random"
# "DB: opt. gap 36.177835993700796"
# ">>>>>> iteration 144:O"
# "DB: random"
# "DB: opt. gap 36.177835993701166"
# ">>>>>> iteration 145:O"
# "DB: random"
# "DB: opt. gap 36.177835993701436"
# ">>>>>> iteration 146:O"
# "DB: random"
# "DB: opt. gap 36.17783599370174"
# ">>>>>> iteration 147:O"
# "DB: random"
# "DB: opt. gap 36.17783599370193"
# ">>>>>> iteration 148:O"
# "DB: random"
# "DB: opt. gap 36.17783599370235"
# ">>>>>> iteration 149:O"
# "DB: random"
# "DB: opt. gap 36.177835993702516"
# ">>>>>> iteration 150:O"
# "DB: CLDRTO method: 2 - Solution at t = 8: not found"
# MC: 5>> Time: 9
# MC: 5>> Time: 10
# MC: 5>> Time: 11
# MC: 5>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.000000206391989"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.764697788053691"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.44318127327588075"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.105624768542199"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.004501609173216541"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 1.7474959371991603e-6"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 5>> Time: 13
# MC: 5>> Time: 14
# MC: 5>> Time: 15
# MC: 5>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.0000047230637987"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.016735052156025727"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.013136540511491195"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0006590531168802124"
# "DB: CLDRTO method: 2 - Solution at t = 16: found"
# MC: 5>> Time: 17
# MC: 5>> Time: 18
# MC: 5>> Time: 19
# MC: 5>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.0000010385861664"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.9326155391651438"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.7846613021352276"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.5330759677292354"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.39016207292833116"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.4186526038846985"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.23039228962485714"
# ">>>>>> iteration 7:O"
# "DB: opt. gap 0.19581670373638732"
# ">>>>>> iteration 8:O"
# "DB: opt. gap 0.056290399599665836"
# ">>>>>> iteration 9:O"
# "DB: opt. gap 0.04304926003419459"
# ">>>>>> iteration 10:O"
# "DB: opt. gap 0.005566049435005057"
# ">>>>>> iteration 11:O"
# "DB: opt. gap 0.002284140995620867"
# ">>>>>> iteration 12:O"
# "DB: opt. gap 0.00034113134805271235"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"
# "DB: MC iter. 6 --> Plant parameter = 0.6040436986827896"
# "Nominal solution at t = 0: found"
# MC: 6>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 6>> Time: 2
# MC: 6>> Time: 3
# MC: 6>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 6>> Time: 5
# MC: 6>> Time: 6
# MC: 6>> Time: 7
# MC: 6>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 6>> Time: 9
# MC: 6>> Time: 10
# MC: 6>> Time: 11
# MC: 6>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 6>> Time: 13
# MC: 6>> Time: 14
# MC: 6>> Time: 15
# MC: 6>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 6>> Time: 17
# MC: 6>> Time: 18
# MC: 6>> Time: 19
# MC: 6>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 6>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.8130703643321596e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 6>> Time: 2
# MC: 6>> Time: 3
# MC: 6>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.0000000182455477"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004986397208744751"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004613228769326337"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 5.086411688845259e-6"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 6>> Time: 5
# MC: 6>> Time: 6
# MC: 6>> Time: 7
# MC: 6>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.0000003005938194"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.6713659703944326"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 1.6326918613781355e-5"
# "DB: CLDRTO method: 2 - Solution at t = 8: found"
# MC: 6>> Time: 9
# MC: 6>> Time: 10
# MC: 6>> Time: 11
# MC: 6>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.0000045235108261"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.292783780261514"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.14182391596827285"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.048509508062655825"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.004606207709920363"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.006216404446510893"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.0005507741029709906"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 6>> Time: 13
# MC: 6>> Time: 14
# MC: 6>> Time: 15
# MC: 6>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.0000004757984502"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.11077839703810072"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.08256871307637274"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0013497952550095506"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 2.8537373901501724e-6"
# "DB: CLDRTO method: 2 - Solution at t = 16: found"
# MC: 6>> Time: 17
# MC: 6>> Time: 18
# MC: 6>> Time: 19
# MC: 6>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.00000009370283"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.17774352166089427"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.061960716211223614"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.01770793145580461"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.004613687717904739"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.0012128242763051911"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.0003184486516596341"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"
# "DB: MC iter. 7 --> Plant parameter = 0.6581049734542704"
# "Nominal solution at t = 0: found"
# MC: 7>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 7>> Time: 2
# MC: 7>> Time: 3
# MC: 7>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 7>> Time: 5
# MC: 7>> Time: 6
# MC: 7>> Time: 7
# MC: 7>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 7>> Time: 9
# MC: 7>> Time: 10
# MC: 7>> Time: 11
# MC: 7>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 7>> Time: 13
# MC: 7>> Time: 14
# MC: 7>> Time: 15
# MC: 7>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 7>> Time: 17
# MC: 7>> Time: 18
# MC: 7>> Time: 19
# MC: 7>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 7>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.8133472850555363e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 7>> Time: 2
# MC: 7>> Time: 3
# MC: 7>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.0000000215719416"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.006434418091681077"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.005581240890222329"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.0143114514810005e-5"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 7>> Time: 5
# MC: 7>> Time: 6
# MC: 7>> Time: 7
# MC: 7>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.000001543896272"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.8083984319394154"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.5574767707940145"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.29713220202891505"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.13945646830742348"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.06690707668502718"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.9642765984221796"
# ">>>>>> iteration 7:O"
# "DB: opt. gap 9.830305833580406"
# ">>>>>> iteration 8:O"
# "DB: opt. gap 9.830305678351305"
# ">>>>>> iteration 9:O"
# "DB: random"
# "DB: opt. gap 9.830305517034175"
# ">>>>>> iteration 10:O"
# "DB: random"
# "DB: opt. gap 9.830305348277822"
# ">>>>>> iteration 11:O"
# "DB: random"
# "DB: opt. gap 9.83030517016484"
# ">>>>>> iteration 12:O"
# "DB: random"
# "DB: opt. gap 9.830304979805307"
# ">>>>>> iteration 13:O"
# "DB: random"
# "DB: opt. gap 9.830304772462977"
# ">>>>>> iteration 14:O"
# "DB: random"
# "DB: opt. gap 9.830109987805761"
# ">>>>>> iteration 15:O"
# "DB: random"
# "DB: opt. gap 9.830109480502388"
# ">>>>>> iteration 16:O"
# "DB: random"
# "DB: opt. gap 9.830673667894828"
# ">>>>>> iteration 17:O"
# "DB: random"
# "DB: opt. gap 9.830301288705153"
# ">>>>>> iteration 18:O"
# "DB: random"
# "DB: opt. gap 9.830301288824838"
# ">>>>>> iteration 19:O"
# "DB: random"
# "DB: opt. gap 9.830301288813244"
# ">>>>>> iteration 20:O"
# "DB: random"
# "DB: opt. gap 9.83030128889583"
# ">>>>>> iteration 21:O"
# "DB: random"
# "DB: opt. gap 9.830301288821449"
# ">>>>>> iteration 22:O"
# "DB: random"
# "DB: opt. gap 9.83030128874738"
# ">>>>>> iteration 23:O"
# "DB: random"
# "DB: opt. gap 9.83030128877452"
# ">>>>>> iteration 24:O"
# "DB: random"
# "DB: opt. gap 9.830301288759781"
# ">>>>>> iteration 25:O"
# "DB: random"
# "DB: opt. gap 9.830301288800761"
# ">>>>>> iteration 26:O"
# "DB: random"
# "DB: opt. gap 9.830301288828714"
# ">>>>>> iteration 27:O"
# "DB: random"
# "DB: opt. gap 9.830301288705888"
# ">>>>>> iteration 28:O"
# "DB: random"
# "DB: opt. gap 9.830301288810645"
# ">>>>>> iteration 29:O"
# "DB: random"
# "DB: opt. gap 9.83030128881012"
# ">>>>>> iteration 30:O"
# "DB: random"
# "DB: opt. gap 9.830301288838227"
# ">>>>>> iteration 31:O"
# "DB: random"
# "DB: opt. gap 9.83030128885871"
# ">>>>>> iteration 32:O"
# "DB: random"
# "DB: opt. gap 9.830301288816967"
# ">>>>>> iteration 33:O"
# "DB: random"
# "DB: opt. gap 9.830301289058552"
# ">>>>>> iteration 34:O"
# "DB: random"
# "DB: opt. gap 9.830301288823435"
# ">>>>>> iteration 35:O"
# "DB: random"
# "DB: opt. gap 9.830301288853345"
# ">>>>>> iteration 36:O"
# "DB: random"
# "DB: opt. gap 9.830301288832041"
# ">>>>>> iteration 37:O"
# "DB: random"
# "DB: opt. gap 9.830301288826359"
# ">>>>>> iteration 38:O"
# "DB: random"
# "DB: opt. gap 9.830301288874617"
# ">>>>>> iteration 39:O"
# "DB: random"
# "DB: opt. gap 9.830301288839008"
# ">>>>>> iteration 40:O"
# "DB: random"
# "DB: opt. gap 9.830301289087677"
# ">>>>>> iteration 41:O"
# "DB: random"
# "DB: opt. gap 9.830301288861722"
# ">>>>>> iteration 42:O"
# "DB: random"
# "DB: opt. gap 9.830301288851212"
# ">>>>>> iteration 43:O"
# "DB: random"
# "DB: opt. gap 9.830301289097017"
# ">>>>>> iteration 44:O"
# "DB: random"
# "DB: opt. gap 9.83030128888045"
# ">>>>>> iteration 45:O"
# "DB: random"
# "DB: opt. gap 9.830301288281124"
# ">>>>>> iteration 46:O"
# "DB: random"
# "DB: opt. gap 9.830301288709787"
# ">>>>>> iteration 47:O"
# "DB: random"
# "DB: opt. gap 9.830301288854661"
# ">>>>>> iteration 48:O"
# "DB: random"
# "DB: opt. gap 9.830301288786506"
# ">>>>>> iteration 49:O"
# "DB: random"
# "DB: opt. gap 9.830301288743145"
# ">>>>>> iteration 50:O"
# "DB: random"
# "DB: opt. gap 9.830301288875054"
# ">>>>>> iteration 51:O"
# "DB: random"
# "DB: opt. gap 9.830301289241818"
# ">>>>>> iteration 52:O"
# "DB: random"
# "DB: opt. gap 9.83030128927977"
# ">>>>>> iteration 53:O"
# "DB: random"
# "DB: opt. gap 9.830301288919246"
# ">>>>>> iteration 54:O"
# "DB: random"
# "DB: opt. gap 9.830301288831745"
# ">>>>>> iteration 55:O"
# "DB: random"
# "DB: opt. gap 9.83030128827104"
# ">>>>>> iteration 56:O"
# "DB: random"
# "DB: opt. gap 9.83030128840176"
# ">>>>>> iteration 57:O"
# "DB: random"
# "DB: opt. gap 9.830301288269139"
# ">>>>>> iteration 58:O"
# "DB: random"
# ...
# ">>>>>> iteration 44:O"
# "DB: random"
# "DB: opt. gap 2.4670363099654526"
# ">>>>>> iteration 45:O"
# "DB: random"
# "DB: opt. gap 2.467036309964747"
# ">>>>>> iteration 46:O"
# "DB: random"
# "DB: opt. gap 2.4670363099641985"
# ">>>>>> iteration 47:O"
# "DB: random"
# "DB: opt. gap 2.4670363099635497"
# ">>>>>> iteration 48:O"
# "DB: random"
# "DB: opt. gap 2.4670363099634884"
# ">>>>>> iteration 49:O"
# "DB: random"
# "DB: opt. gap 2.4670363099626518"
# ">>>>>> iteration 50:O"
# "DB: random"
# "DB: opt. gap 2.4670363099613177"
# ">>>>>> iteration 51:O"
# "DB: random"
# "DB: opt. gap 2.4670363099605535"
# ">>>>>> iteration 52:O"
# "DB: random"
# "DB: opt. gap 2.467036309959904"
# ">>>>>> iteration 53:O"
# "DB: random"
# "DB: opt. gap 2.467036309955932"
# ">>>>>> iteration 54:O"
# "DB: random"
# "DB: opt. gap 2.467036309958138"
# ">>>>>> iteration 55:O"
# "DB: random"
# "DB: opt. gap 2.4670363099576926"
# ">>>>>> iteration 56:O"
# "DB: random"
# "DB: opt. gap 2.467036309956335"
# ">>>>>> iteration 57:O"
# "DB: random"
# "DB: opt. gap 2.4670363099558474"
# ">>>>>> iteration 58:O"
# "DB: random"
# "DB: opt. gap 2.4670363099544335"
# ">>>>>> iteration 59:O"
# "DB: random"
# "DB: opt. gap 2.4670363099538197"
# ">>>>>> iteration 60:O"
# "DB: random"
# "DB: opt. gap 2.467036309952348"
# ">>>>>> iteration 61:O"
# "DB: random"
# "DB: opt. gap 2.4670363099525225"
# ">>>>>> iteration 62:O"
# "DB: random"
# "DB: opt. gap 2.4670363099507537"
# ">>>>>> iteration 63:O"
# "DB: random"
# "DB: opt. gap 2.467036309987389"
# ">>>>>> iteration 64:O"
# "DB: random"
# "DB: opt. gap 2.4670363099481403"
# ">>>>>> iteration 65:O"
# "DB: random"
# "DB: opt. gap 2.467036309946805"
# ">>>>>> iteration 66:O"
# "DB: random"
# "DB: opt. gap 2.46703630994716"
# ">>>>>> iteration 67:O"
# "DB: random"
# "DB: opt. gap 2.4670363099438752"
# ">>>>>> iteration 68:O"
# "DB: random"
# "DB: opt. gap 2.4670363099420047"
# ">>>>>> iteration 69:O"
# "DB: random"
# "DB: opt. gap 2.467036309978203"
# ">>>>>> iteration 70:O"
# "DB: random"
# "DB: opt. gap 2.467036309940209"
# ">>>>>> iteration 71:O"
# "DB: random"
# "DB: opt. gap 2.467036309939413"
# ">>>>>> iteration 72:O"
# "DB: random"
# "DB: opt. gap 2.467036309935599"
# ">>>>>> iteration 73:O"
# "DB: random"
# "DB: opt. gap 2.4670363099360992"
# ">>>>>> iteration 74:O"
# "DB: random"
# "DB: opt. gap 2.467036309933995"
# ">>>>>> iteration 75:O"
# "DB: random"
# "DB: opt. gap 2.467036309936513"
# ">>>>>> iteration 76:O"
# "DB: random"
# "DB: opt. gap 2.4670363099346004"
# ">>>>>> iteration 77:O"
# "DB: random"
# "DB: opt. gap 2.4670363099301658"
# ">>>>>> iteration 78:O"
# "DB: random"
# "DB: opt. gap 2.4670363099316037"
# ">>>>>> iteration 79:O"
# "DB: random"
# "DB: opt. gap 2.4670363099355637"
# ">>>>>> iteration 80:O"
# "DB: random"
# "DB: opt. gap 2.467036309928668"
# ">>>>>> iteration 81:O"
# "DB: random"
# "DB: opt. gap 2.4670363099273978"
# ">>>>>> iteration 82:O"
# "DB: random"
# "DB: opt. gap 2.4670363099257973"
# ">>>>>> iteration 83:O"
# "DB: random"
# "DB: opt. gap 2.467036309920657"
# ">>>>>> iteration 84:O"
# "DB: random"
# "DB: opt. gap 2.4670363099223773"
# ">>>>>> iteration 85:O"
# "DB: random"
# "DB: opt. gap 2.4670363098905543"
# ">>>>>> iteration 86:O"
# "DB: random"
# "DB: opt. gap 2.4670363099177317"
# ">>>>>> iteration 87:O"
# "DB: random"
# "DB: opt. gap 2.4670363099173733"
# ">>>>>> iteration 88:O"
# "DB: random"
# "DB: opt. gap 2.4670363099233374"
# ">>>>>> iteration 89:O"
# "DB: random"
# "DB: opt. gap 2.4670363099215367"
# ">>>>>> iteration 90:O"
# "DB: random"
# "DB: opt. gap 2.4670363099125927"
# ">>>>>> iteration 91:O"
# "DB: random"
# "DB: opt. gap 2.4670363099106183"
# ">>>>>> iteration 92:O"
# "DB: random"
# "DB: opt. gap 2.467036309915325"
# ">>>>>> iteration 93:O"
# "DB: random"
# "DB: opt. gap 2.467036309906599"
# ">>>>>> iteration 94:O"
# "DB: random"
# "DB: opt. gap 2.467036309904693"
# ">>>>>> iteration 95:O"
# "DB: random"
# "DB: opt. gap 2.467036309902771"
# ">>>>>> iteration 96:O"
# "DB: random"
# "DB: opt. gap 2.467036309900821"
# ">>>>>> iteration 97:O"
# "DB: random"
# "DB: opt. gap 2.4670363099234605"
# ">>>>>> iteration 98:O"
# "DB: random"
# "DB: opt. gap 2.4670363099294117"
# ">>>>>> iteration 99:O"
# "DB: random"
# "DB: opt. gap 2.467036309919897"
# ">>>>>> iteration 100:O"
# "DB: random"
# "DB: opt. gap 2.4670363098904753"
# ">>>>>> iteration 101:O"
# "DB: random"
# "DB: opt. gap 2.4670363099351453"
# ">>>>>> iteration 102:O"
# "DB: random"
# "DB: opt. gap 2.467036309888519"
# ">>>>>> iteration 103:O"
# "DB: random"
# "DB: opt. gap 2.467036309886365"
# ">>>>>> iteration 104:O"
# "DB: random"
# "DB: opt. gap 2.467036309884192"
# ">>>>>> iteration 105:O"
# "DB: random"
# "DB: opt. gap 2.4670363098819768"
# ">>>>>> iteration 106:O"
# "DB: random"
# "DB: opt. gap 2.467036309879749"
# ">>>>>> iteration 107:O"
# "DB: random"
# "DB: opt. gap 2.4670363098774786"
# ">>>>>> iteration 108:O"
# "DB: random"
# "DB: opt. gap 2.4670363098756085"
# ">>>>>> iteration 109:O"
# "DB: random"
# "DB: opt. gap 2.467036309874097"
# ">>>>>> iteration 110:O"
# "DB: random"
# "DB: opt. gap 2.4670363098704025"
# ">>>>>> iteration 111:O"
# "DB: random"
# "DB: opt. gap 2.4670363098754216"
# ">>>>>> iteration 112:O"
# "DB: random"
# "DB: opt. gap 2.4670363098657075"
# ">>>>>> iteration 113:O"
# "DB: random"
# "DB: opt. gap 2.4670363098632957"
# ">>>>>> iteration 114:O"
# "DB: random"
# "DB: opt. gap 2.467036309860803"
# ">>>>>> iteration 115:O"
# "DB: random"
# "DB: opt. gap 2.4670363098583663"
# ">>>>>> iteration 116:O"
# "DB: random"
# "DB: opt. gap 2.4670363098558066"
# ">>>>>> iteration 117:O"
# "DB: random"
# "DB: opt. gap 2.4670363098509283"
# ">>>>>> iteration 118:O"
# "DB: random"
# "DB: opt. gap 2.467036309850828"
# ">>>>>> iteration 119:O"
# "DB: random"
# "DB: opt. gap 2.46703630983173"
# ">>>>>> iteration 120:O"
# "DB: random"
# "DB: opt. gap 2.467036309845436"
# ">>>>>> iteration 121:O"
# "DB: random"
# "DB: opt. gap 2.4670363098430736"
# ">>>>>> iteration 122:O"
# "DB: random"
# "DB: opt. gap 2.4670363098518813"
# ">>>>>> iteration 123:O"
# "DB: random"
# "DB: opt. gap 2.467036309837361"
# ">>>>>> iteration 124:O"
# "DB: random"
# "DB: opt. gap 2.4670363098344605"
# ">>>>>> iteration 125:O"
# "DB: random"
# "DB: opt. gap 2.4670363098313666"
# ">>>>>> iteration 126:O"
# "DB: random"
# "DB: opt. gap 2.4670363097705055"
# ">>>>>> iteration 127:O"
# "DB: random"
# "DB: opt. gap 2.467036309830134"
# ">>>>>> iteration 128:O"
# "DB: random"
# "DB: opt. gap 2.4670363097990102"
# ">>>>>> iteration 129:O"
# "DB: random"
# "DB: opt. gap 2.4670363098277357"
# ">>>>>> iteration 130:O"
# "DB: random"
# "DB: opt. gap 2.467036309817376"
# ">>>>>> iteration 131:O"
# "DB: random"
# "DB: opt. gap 2.4670363098169763"
# ">>>>>> iteration 132:O"
# "DB: random"
# "DB: opt. gap 2.4670363098085297"
# ">>>>>> iteration 133:O"
# "DB: random"
# "DB: opt. gap 2.4670363098085195"
# ">>>>>> iteration 134:O"
# "DB: random"
# "DB: opt. gap 2.467036309805341"
# ">>>>>> iteration 135:O"
# "DB: random"
# "DB: opt. gap 2.467036309802246"
# ">>>>>> iteration 136:O"
# "DB: random"
# "DB: opt. gap 2.4670363098028663"
# ">>>>>> iteration 137:O"
# "DB: random"
# "DB: opt. gap 2.4670363098709647"
# ">>>>>> iteration 138:O"
# "DB: random"
# "DB: opt. gap 2.467036309792753"
# ">>>>>> iteration 139:O"
# "DB: random"
# "DB: opt. gap 2.4670363097909505"
# ">>>>>> iteration 140:O"
# "DB: random"
# "DB: opt. gap 2.467036309785588"
# ">>>>>> iteration 141:O"
# "DB: random"
# "DB: opt. gap 2.4670363097832824"
# ">>>>>> iteration 142:O"
# "DB: random"
# "DB: opt. gap 2.467036309779909"
# ">>>>>> iteration 143:O"
# "DB: random"
# "DB: opt. gap 2.4670363097764834"
# ">>>>>> iteration 144:O"
# "DB: random"
# "DB: opt. gap 2.4670363097731256"
# ">>>>>> iteration 145:O"
# "DB: random"
# "DB: opt. gap 2.467036309770033"
# ">>>>>> iteration 146:O"
# "DB: random"
# "DB: opt. gap 2.4670363098893424"
# ">>>>>> iteration 147:O"
# "DB: random"
# "DB: opt. gap 2.4670363097631505"
# ">>>>>> iteration 148:O"
# "DB: random"
# "DB: opt. gap 2.4670363097598855"
# ">>>>>> iteration 149:O"
# "DB: random"
# "DB: opt. gap 2.4670363097551125"
# ">>>>>> iteration 150:O"
# "DB: CLDRTO method: 2 - Solution at t = 8: not found"
# MC: 18>> Time: 9
# MC: 18>> Time: 10
# MC: 18>> Time: 11
# MC: 18>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.0000010929567318"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.006227111704107468"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004505895639535525"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0004753262415729337"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 18>> Time: 13
# MC: 18>> Time: 14
# MC: 18>> Time: 15
# MC: 18>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.0000039497119146"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.8121626367572236"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.5582658762255307"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.2691402570217606"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.10235939681044998"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.031645684131836556"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.0138071998233782"
# ">>>>>> iteration 7:O"
# "DB: opt. gap 0.0033189860286254916"
# ">>>>>> iteration 8:O"
# "DB: opt. gap 0.00045398102733900145"
# "DB: CLDRTO method: 2 - Solution at t = 16: found"
# MC: 18>> Time: 17
# MC: 18>> Time: 18
# MC: 18>> Time: 19
# MC: 18>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.0000001829205047"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.09141479443137722"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.0760847764492412"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0004465768770039553"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"
# "DB: MC iter. 19 --> Plant parameter = 0.8945638072097966"
# "Nominal solution at t = 0: found"
# MC: 19>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 19>> Time: 2
# MC: 19>> Time: 3
# MC: 19>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 19>> Time: 5
# MC: 19>> Time: 6
# MC: 19>> Time: 7
# MC: 19>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 19>> Time: 9
# MC: 19>> Time: 10
# MC: 19>> Time: 11
# MC: 19>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 19>> Time: 13
# MC: 19>> Time: 14
# MC: 19>> Time: 15
# MC: 19>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 19>> Time: 17
# MC: 19>> Time: 18
# MC: 19>> Time: 19
# MC: 19>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 19>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.8133185794065245e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 19>> Time: 2
# MC: 19>> Time: 3
# MC: 19>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.0000000311413082"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.025794934233880462"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.02399852767267959"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 3.230972747274506e-5"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 19>> Time: 5
# MC: 19>> Time: 6
# MC: 19>> Time: 7
# MC: 19>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.000000011603331"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.0038823576522553894"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.0025075318738959507"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.003482154931684773"
# ">>>>>> iteration 4:O"
# "DB: random"
# "DB: opt. gap 1.367976335070137e-5"
# "DB: CLDRTO method: 2 - Solution at t = 8: found"
# MC: 19>> Time: 9
# MC: 19>> Time: 10
# MC: 19>> Time: 11
# MC: 19>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.0000000027331257"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.20309864276095305"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.07092985084020274"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0236610331432598"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.006507054436635996"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.006221346120692937"
# ">>>>>> iteration 6:O"
# "DB: random"
# "DB: opt. gap 0.00014185924555973825"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 19>> Time: 13
# MC: 19>> Time: 14
# MC: 19>> Time: 15
# MC: 19>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.000000003664187"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.022164679889963252"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.00642331898849991"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0017004097879096166"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 5.7041393540188496e-8"
# "DB: CLDRTO method: 2 - Solution at t = 16: found"
# MC: 19>> Time: 17
# MC: 19>> Time: 18
# MC: 19>> Time: 19
# MC: 19>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.000000004835308"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.005973763870475933"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.003990245347692185"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0011034259610016276"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.0002686206978231235"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"
# "DB: MC iter. 20 --> Plant parameter = 0.8229428173011364"
# "Nominal solution at t = 0: found"
# MC: 20>> Time: 1
# "DB: CLDRTO method: 1 - Solution at t = 1: found"
# MC: 20>> Time: 2
# MC: 20>> Time: 3
# MC: 20>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: CLDRTO method: 1 - Solution at t = 4: found"
# MC: 20>> Time: 5
# MC: 20>> Time: 6
# MC: 20>> Time: 7
# MC: 20>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: CLDRTO method: 1 - Solution at t = 8: found"
# MC: 20>> Time: 9
# MC: 20>> Time: 10
# MC: 20>> Time: 11
# MC: 20>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: CLDRTO method: 1 - Solution at t = 12: found"
# MC: 20>> Time: 13
# MC: 20>> Time: 14
# MC: 20>> Time: 15
# MC: 20>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: CLDRTO method: 1 - Solution at t = 16: found"
# MC: 20>> Time: 17
# MC: 20>> Time: 18
# MC: 20>> Time: 19
# MC: 20>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: CLDRTO method: 1 - Solution at t = 20: found"
# "Nominal solution at t = 0: found"
# MC: 20>> Time: 1
# "DB: opt. gap 1.0000000052636144"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.004311405460636164"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.004100240012674004"
# ">>>>>> iteration 3:O"
# "DB: random"
# "DB: opt. gap 2.8130110060370254e-6"
# "DB: CLDRTO method: 2 - Solution at t = 1: found"
# MC: 20>> Time: 2
# MC: 20>> Time: 3
# MC: 20>> Time: 4
# "DB: Nominal solution at t = 4: found"
# "DB: opt. gap 1.000000030478356"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.022712814258183868"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.02093471595482542"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 2.252841387966323e-5"
# "DB: CLDRTO method: 2 - Solution at t = 4: found"
# MC: 20>> Time: 5
# MC: 20>> Time: 6
# MC: 20>> Time: 7
# MC: 20>> Time: 8
# "DB: Nominal solution at t = 8: found"
# "DB: opt. gap 1.0000000838950083"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.09425070135454063"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.0357574337094278"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0002573872271687944"
# "DB: CLDRTO method: 2 - Solution at t = 8: found"
# MC: 20>> Time: 9
# MC: 20>> Time: 10
# MC: 20>> Time: 11
# MC: 20>> Time: 12
# "DB: Nominal solution at t = 12: found"
# "DB: opt. gap 1.0000000036104957"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.12349208027628686"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.04294704930304434"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.01332198916821164"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.007570215856824391"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.000685955364402799"
# "DB: CLDRTO method: 2 - Solution at t = 12: found"
# MC: 20>> Time: 13
# MC: 20>> Time: 14
# MC: 20>> Time: 15
# MC: 20>> Time: 16
# "DB: Nominal solution at t = 16: found"
# "DB: opt. gap 1.000000009016481"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.37360417946098823"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.1487903281486418"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.054578258008438046"
# ">>>>>> iteration 4:O"
# "DB: opt. gap 0.01539058407507811"
# ">>>>>> iteration 5:O"
# "DB: opt. gap 0.005048536239366997"
# ">>>>>> iteration 6:O"
# "DB: opt. gap 0.0022711282194296323"
# ">>>>>> iteration 7:O"
# "DB: opt. gap 0.0009452804635857622"
# "DB: CLDRTO method: 2 - Solution at t = 16: found"
# MC: 20>> Time: 17
# MC: 20>> Time: 18
# MC: 20>> Time: 19
# MC: 20>> Time: 20
# "DB: Nominal solution at t = 20: found"
# "DB: opt. gap 1.000000008701109"
# ">>>>>> iteration 1:O"
# "DB: opt. gap 0.005730676427695635"
# ">>>>>> iteration 2:O"
# "DB: opt. gap 0.0025627846867140066"
# ">>>>>> iteration 3:O"
# "DB: opt. gap 0.0006341279612531202"
# "DB: CLDRTO method: 2 - Solution at t = 20: found"

# %% [markdown]
# Preparing plot

# %%
# time series for plotting
ts = Vector{Float64}(undef,nsim) 
for i in 1:nsim
    ts[i] = 1*i
end

# one subplot for each method
num_subplots = 2

# Creating color array
CList = reshape( range(colorant"red", stop=colorant"blue",length=n_MC), 1, n_MC);
MList =[:square, :circle];

# %% [markdown]
# Computing statistics

# %%
# Extracting solution for plotting --> monolithic vs. decomposed 
CMean = mean(CPlant,dims=2)
PMean = mean(PPlant,dims=2)
CinMean = mean(CinPlant,dims=2)
yspMean = mean(yspPlant,dims=2);

# %% [markdown]
# Plotting receipts

# %%
@userplot MC_Plot
@recipe function f(h::MC_Plot)
        
    if length(h.args) < 5 
        ylab, x, y_bar, y = h.args
    else
        ylab, x, y_bar, y, lim_u = h.args
    end
    
    # set up the subplots
    # these are common to both marginal histograms
    legend := false
    layout :=  (2,1)
    grid := true
    gridlinewidth --> 2
    latex := true
    linecolor := :black
    
    for mm in 1:2
        # labels 
        ylabel := ylab
        if mm == 2
            xlabel := "time [min]"
        end
        
        # DATA PLOTTING
        # upper bound
        if length(h.args) > 4 
            # lower bound
            @series begin
                seriestype := :path
                linestyle := :dot
                subplot := mm
                x, lim_u*ones(length(x))
            end
        end

        # average MC value
        @series begin
            seriestype := :path
            linewidth := 3
            markercolor := :black
            markerstrokecolor := :black
            markersize := 3
            
            if mm == 1
                linestyle := :solid
                markershape := :circle
            else
                linestyle := :dashdot
                markershape := :rect
            end
            
            subplot := mm
            x, y_bar[:,mm]
            
        end
        
        for nn in 1:n_MC
            @series begin
                seriestype := :path
                linewidth := 2
                linealpha := 0.1
                subplot := mm
                x, y[:,nn,mm]
            end
        end # MC loop
    end # mono/dec loop 
end

# %%
@userplot MC_Comp
@recipe function f(h::MC_Comp)
        
    if length(h.args) < 4 
        ylab, x, y_bar = h.args
    else
        ylab, x, y_bar, lim_u = h.args
    end
    
    # set up the subplots
    # these are common to both marginal histograms    
    grid := true
    gridlinewidth --> 2
    
    linecolor := :black
    markercolor := :black
    markerstrokecolor := :black
    markersize := 3
    
    # axis labels 
    ylabel := ylab
    xlabel := "time [min]"

    # legend
    legend := true
    latex := true
    labels = ["Mono.","Decom."] 
    
    # DATA PLOTTING
    # upper bound
    if length(h.args) > 3
        # lower bound
        @series begin
            seriestype := :path
            linestyle := :dot
            label --> ""
            x, lim_u*ones(length(x))
        end
    end

    # monolithic
    @series begin
        seriestype := :path
        linewidth := 3
        linestyle := :solid
        markershape := :circle
        label --> "Mono."
        x, y_bar[:,1]
    end 
    
    # decomposed
    @series begin
        seriestype := :path
        linewidth := 3
        linestyle := :dashdot
        markershape := :rect
        label --> "Deco."
        x, y_bar[:,2]
    end 
end

# %% [markdown]
# ## Monte Carlo Iterations

# %% [markdown]
# - Biomass

# %%
mc_plot(L"P [g/l]",ts,PMean[:,1,:],PPlant)

# %% [markdown]
# - Biomass Setpoint

# %%
mc_plot(L"P^{SP} [g/L]",ts,yspMean[:,1,:],yspPlant,yspMax)

# %% [markdown]
# - Inputs

# %%
mc_plot(L"C_{in} [g/L]",ts,CinMean[:,1,:],CinPlant,Cin_max)

# %% [markdown]
# ## Comparing Average Behavior

# %% [markdown]
# - Biomass

# %%
mc_comp(L"P [g/L]",ts,PMean[:,1,:])

# %% [markdown]
# - Biomass Setpoint

# %%
mc_comp(L"P^{SP} [g/L]",ts,yspMean[:,1,:],yspMax)

# %% [markdown]
# - Inputs

# %%
mc_comp(L"C_{in} [g/L]",ts,CinMean[:,1,:],Cin_max)
